# %%
import cv2
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# --------------------------
# Input and output paths
# --------------------------
image_path = r"C:\Users\DELL\Downloads\fullImages\fullImages\set1_Image_01_40x_bf_02.png"
output_folder = r"C:\Users\DELL\Downloads\40x_bf_02_qwerty5_4_statistics_regrowth_all"
os.makedirs(output_folder, exist_ok=True)

# Scale factor (µm/px)
scale_factor = 0.136

# --------------------------
# Tunables
# --------------------------
TISSUE_OVERLAP_MIN = 0.50
MAX_MEAN_INTENSITY = 245
MIN_CIRCULARITY = 0.10
MIN_CONTOUR_AREA = 20
MAX_CONTOUR_AREA = 2000000
MIN_SOLIDITY = 0.3  # adjust based on dataset

# --------------------------
# Helpers
# --------------------------
def darken_and_sharpen(image):
    darkened = cv2.convertScaleAbs(image, alpha=1.5, beta=-20)
    sharpen_kernel = np.array([[0, -1, 0],
                               [-1, 5, -1],
                               [0, -1, 0]])
    return cv2.filter2D(darkened, -1, sharpen_kernel)

def build_tissue_mask(full_image):
    hsv = cv2.cvtColor(full_image, cv2.COLOR_BGR2HSV)
    H, S, V = cv2.split(hsv)
    sat_mask = cv2.inRange(S, 15, 255)
    not_too_bright = cv2.inRange(V, 0, 250)
    mask = cv2.bitwise_and(sat_mask, not_too_bright)
    k = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (7, 7))
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, k, iterations=1)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, k, iterations=2)
    return mask

def contour_overlap_ratio(contour, mask):
    c_mask = np.zeros(mask.shape, dtype=np.uint8)
    cv2.drawContours(c_mask, [contour], -1, 255, -1)
    inter = cv2.bitwise_and(c_mask, mask)
    area_c = cv2.countNonZero(c_mask)
    area_i = cv2.countNonZero(inter)
    return area_i / float(area_c) if area_c > 0 else 0.0

def mean_intensity_in_contour(gray, contour):
    m = np.zeros(gray.shape, dtype=np.uint8)
    cv2.drawContours(m, [contour], -1, 255, -1)
    return cv2.mean(gray, mask=m)[0]

def circularity(contour):
    a = cv2.contourArea(contour)
    p = cv2.arcLength(contour, True)
    return 4 * np.pi * a / (p * p + 1e-6) if p > 0 else 0

# --------------------------
# Main patch processing
# --------------------------
def process_patch(patch, mask_patch, x_offset, y_offset, axon_data, object_counter, output_image):
    patch = darken_and_sharpen(patch)
    gray = cv2.cvtColor(patch, cv2.COLOR_BGR2GRAY)

    # Contrast enhancement
    clahe = cv2.createCLAHE(clipLimit=2.5, tileGridSize=(8, 8))
    enhanced = clahe.apply(gray)

    # Use both Otsu + adaptive threshold (union of both)
    blurred = cv2.GaussianBlur(enhanced, (3, 3), 0)
    _, otsu = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    adaptive = cv2.adaptiveThreshold(
        blurred, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
        cv2.THRESH_BINARY_INV, 35, 2
    )
    thresh = cv2.bitwise_or(otsu, adaptive)

    # Clean
    kernel = np.ones((3, 3), np.uint8)
    cleaned = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=1)

    contours, hierarchy = cv2.findContours(cleaned, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    if hierarchy is None:
        return object_counter
    hierarchy = hierarchy[0]

    for i, contour in enumerate(contours):
        # only outer contours
        if hierarchy[i][3] != -1:
            continue

        area = cv2.contourArea(contour)
        if area < MIN_CONTOUR_AREA or area > MAX_CONTOUR_AREA:
            continue

        overlap = contour_overlap_ratio(contour, mask_patch)
        if overlap < TISSUE_OVERLAP_MIN:
            continue

        hull = cv2.convexHull(contour)
        solidity = area / (cv2.contourArea(hull) + 1e-6)
        circ = circularity(contour)
        if solidity < MIN_SOLIDITY or circ < MIN_CIRCULARITY:
            continue

        # Collect all inner children
        inner_children = []
        for j, child in enumerate(contours):
            if hierarchy[j][3] == i and cv2.contourArea(child) > 30:
                inner_children.append(child)

        if len(inner_children) == 0:
            continue

        # Classification
        axon_type = "mature" if len(inner_children) == 1 else "regrowth_cluster"

        # Largest inner for measurement
        largest_inner = max(inner_children, key=cv2.contourArea)

        # --- Outer ---
        (x_outer, y_outer), outer_radius = cv2.minEnclosingCircle(contour)
        contour_shifted = contour + np.array([x_offset, y_offset])
        x_outer += x_offset
        y_outer += y_offset
        outer_area_px = cv2.contourArea(contour)
        outer_area_um2 = outer_area_px * (scale_factor**2)

        # Draw outer boundary with type-specific color
        outer_color = (255, 0, 0) if axon_type == "mature" else (0, 255, 255)
        cv2.drawContours(output_image, [contour_shifted], -1, outer_color, 1)

        # --- Inner ---
        # --- Inner ---
        inner_radii = []
        inner_areas = []
        
        for inner_c in inner_children:
            (x_inner, y_inner), inner_radius = cv2.minEnclosingCircle(inner_c)
            inner_shifted = inner_c + np.array([x_offset, y_offset])
            cv2.drawContours(output_image, [inner_shifted], -1, (0, 255, 0), 1)  # Draw all in green
            inner_radii.append(inner_radius)
            inner_areas.append(cv2.contourArea(inner_c))
        
        # Use the largest inner contour for metrics
        largest_inner = inner_children[np.argmax(inner_areas)]
        inner_radius = max(inner_radii)
        inner_area_px = max(inner_areas)
        inner_area_um2 = inner_area_px * (scale_factor ** 2)

        # Metrics
        thickness = (outer_radius - inner_radius) * scale_factor
        g_ratio = inner_radius / (outer_radius + 1e-6)
        area_ratio = (inner_area_um2 / outer_area_um2) if outer_area_um2 > 0 else 0
        hole_ratio = inner_area_um2 / (outer_area_um2 + 1e-6)

        # Create masks for mean intensity
        mask_outer = np.zeros(gray.shape, dtype=np.uint8)
        mask_inner = np.zeros(gray.shape, dtype=np.uint8)
        cv2.drawContours(mask_outer, [contour], -1, 255, -1)
        cv2.drawContours(mask_inner, [largest_inner], -1, 255, -1)

        outer_mean = cv2.mean(gray, mask=mask_outer)[0]
        inner_mean = cv2.mean(gray, mask=mask_inner)[0]
        ring_contrast = (outer_mean - inner_mean) / (outer_mean + 1e-6)

        # LAB a-channel mean inside axon center
        lab = cv2.cvtColor(patch, cv2.COLOR_BGR2LAB)
        _, A, _ = cv2.split(lab)
        a_mean_center = cv2.mean(A, mask=mask_inner)[0]

        # Eccentricity
        eccentricity = 0
        if len(contour) >= 5:
            ellipse = cv2.fitEllipse(contour)
            (MA, ma) = ellipse[1]
            if MA > 0:
                eccentricity = np.sqrt(1 - (ma / MA) ** 2)

        axon_data.append({
            "axon_id": object_counter,
            "axon_type": axon_type,
            "num_inner_contours": len(inner_children),
            "center_x": x_outer,
            "center_y": y_outer,
            "outer_radius": outer_radius * scale_factor,
            "inner_radius": inner_radius * scale_factor,
            "thickness": thickness,
            "diameter": (2 * outer_radius) * scale_factor,
            "outer_area": outer_area_um2,
            "inner_area": inner_area_um2,
            "area_ratio": area_ratio,
            "hole_ratio": hole_ratio,
            "ring_contrast": ring_contrast,
            "a_mean_center": a_mean_center,
            "eccentricity": eccentricity,
            "g_ratio": g_ratio
        })

        # Numbering
        cv2.putText(output_image, str(object_counter),
                    (int(x_outer), int(y_outer)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)

        print(f"Axon {object_counter} ({axon_type}):")
        print(f" Center = ({x_outer:.2f}, {y_outer:.2f})")
        print(f" Outer Radius = {outer_radius*scale_factor:.4f} µm")
        print(f" Inner Radius = {inner_radius*scale_factor:.4f} µm")
        print(f" Thickness = {thickness:.4f} µm")
        print(f" Diameter = {(2*outer_radius)*scale_factor:.4f} µm")
        print(f" Outer Area = {outer_area_um2:.4f} µm²")
        print(f" Inner Area = {inner_area_um2:.4f} µm²")
        print(f" G-Ratio = {g_ratio:.4f}")
        print(f" Inner Contours = {len(inner_children)}\n")

        object_counter += 1

    return object_counter

# --------------------------
# Whole image tiling
# --------------------------
def process_image(image_path, patch_size=1024):
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    if image is None:
        raise ValueError("Could not read image")

    tissue_mask_full = build_tissue_mask(image)
    h, w = image.shape[:2]
    output_image = image.copy()
    axon_data = []
    object_counter = 1

    for y in range(0, h, patch_size):
        for x in range(0, w, patch_size):
            patch = image[y:y+patch_size, x:x+patch_size]
            mask_patch = tissue_mask_full[y:y+patch_size, x:x+patch_size]
            object_counter = process_patch(
                patch, mask_patch, x, y, axon_data, object_counter, output_image
            )

    filename = os.path.basename(image_path)
    output_path = os.path.join(output_folder, f"numbered_{filename}")
    cv2.imwrite(output_path, output_image)

    print(f"\nProcessed: {filename}")
    print(f"Axons detected: {len(axon_data)}\n")
    return axon_data, output_image

# --------------------------
# Save data to CSV
# --------------------------
def save_to_csv(axon_data, output_folder, filename="axon_measurements.csv"):
    df = pd.DataFrame(axon_data)
    csv_path = os.path.join(output_folder, filename)
    df.to_csv(csv_path, index=False)
    print(f"✅ Axon data saved to: {csv_path}")
    return df

# --------------------------
# Global Histograms
# --------------------------
def plot_global_histograms(df, output_folder):
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    for col in numeric_cols:
        data = df[col].dropna().values
        if len(data) == 0 or not np.isfinite(data).any():
            continue

        plt.figure(figsize=(6, 4))
        plt.hist(data, bins=30, color="skyblue", edgecolor="black")
        plt.title(f"Global Histogram of {col}")
        plt.xlabel(col)
        plt.ylabel("Frequency")
        plt.grid(True, linestyle="--", alpha=0.6)

        hist_path = os.path.join(output_folder, f"hist_global_{col}.png")
        plt.savefig(hist_path, dpi=150, bbox_inches="tight")
        plt.close()

# --------------------------
# Box, Violin, Scatter Plots
# --------------------------
def visualize_parameters(df, output_folder):
    param_units = {
        "outer_radius": "Outer Radius (µm)",
        "inner_radius": "Inner Radius (µm)",
        "thickness": "Thickness (µm)",
        "diameter": "Diameter (µm)",
        "outer_area": "Outer Area (µm²)",
        "inner_area": "Inner Area (µm²)",
        "area_ratio": "Area Ratio",
        "hole_ratio": "Hole Ratio",
        "ring_contrast": "Ring Contrast",
        "a_mean_center": "A-Mean Center (intensity)",
        "eccentricity": "Eccentricity",
        "g_ratio": "g-ratio",
        "num_inner_contours": "Number of Inner Contours"
    }

    df = df.copy()
    df = df.apply(pd.to_numeric, errors="ignore")

    # 1️⃣ Print all data
    pd.set_option("display.max_rows", None)
    pd.set_option("display.max_columns", None)
    print("\n📋 Axon Data (All rows):")
    print(df)

    # 2️⃣ Individual plots
    for param, label in param_units.items():
        if param not in df:
            continue
        data = df[param].dropna()
        if len(data) == 0:
            continue

        # Boxplot
        plt.figure(figsize=(6, 4))
        sns.boxplot(x=data, color="skyblue")
        plt.title(f"Boxplot of {label}")
        plt.xlabel(label)
        plt.savefig(os.path.join(output_folder, f"box_{param}.png"), dpi=150, bbox_inches="tight")
        plt.close()

        # Violin plot
        plt.figure(figsize=(6, 4))
        sns.violinplot(x=data, inner="box", color="lightgreen")
        plt.title(f"Violin Plot of {label}")
        plt.xlabel(label)
        plt.savefig(os.path.join(output_folder, f"violin_{param}.png"), dpi=150, bbox_inches="tight")
        plt.close()

        # Histogram
        plt.figure(figsize=(6, 4))
        sns.histplot(data, kde=True, bins=30, color="blue")
        plt.title(f"Histogram of {label}")
        plt.xlabel(label)
        plt.ylabel("Count")
        plt.savefig(os.path.join(output_folder, f"hist_{param}.png"), dpi=150, bbox_inches="tight")
        plt.close()

    # Comparative boxplot
    df_melted = df[list(param_units.keys())].melt(var_name="Parameter", value_name="Value")
    plt.figure(figsize=(12, 6))
    sns.boxplot(x="Parameter", y="Value", data=df_melted)
    plt.xticks(rotation=45, ha="right")
    plt.title("Comparative Boxplots of Axon Parameters")
    plt.ylabel("Value (with units depending on parameter)")
    plt.tight_layout()
    plt.savefig(os.path.join(output_folder, "comparative_boxplots.png"), dpi=150)
    plt.close()

    # Scatter plot matrix
    clean_df = df[list(param_units.keys())].dropna()
    if not clean_df.empty:
        pairplot = sns.pairplot(clean_df, corner=True, plot_kws={"alpha": 0.5, "s": 20})
        pairplot.fig.suptitle("Scatter Plot Matrix of Axon Parameters", y=1.02)
        pairplot.savefig(os.path.join(output_folder, "scatter_matrix.png"), dpi=150, bbox_inches="tight")
        plt.close("all")

    print(f"\n✅ Plots saved in '{output_folder}'")

# --------------------------
# Summary counts
# --------------------------
def save_summary(df, output_folder):
    mature_count = (df["axon_type"] == "mature").sum()
    regrowth_clusters = (df["axon_type"] == "regrowth_cluster").sum()
    total_regrowth_axons = df.loc[df["axon_type"] == "regrowth_cluster", "num_inner_contours"].sum()

    summary_text = (
        f"Number of mature axons: {mature_count}\n"
        f"Number of regrowth clusters: {regrowth_clusters}\n"
        f"Number of total regrowth axons: {total_regrowth_axons}\n"
    )

    print("\n📊 Summary:\n" + summary_text)

    with open(os.path.join(output_folder, "summary.txt"), "w") as f:
        f.write(summary_text)

# --------------------------
# Run Pipeline
# --------------------------
axon_data, output_image = process_image(image_path, patch_size=1024)
df = save_to_csv(axon_data, output_folder)
plot_global_histograms(df, output_folder)
visualize_parameters(df, output_folder)
save_summary(df, output_folder)

print(f"\n✅ All CSV + plots + summary saved in '{output_folder}'")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_27148\2253773320.py:187: RuntimeWarning: invalid value encountered in sqrt
#   eccentricity = np.sqrt(1 - (ma / MA) ** 2)
# Axon 1 (mature):
#  Center = (2514.93, 2207.17)
#  Outer Radius = 3.6420 µm
#  Inner Radius = 0.6269 µm
#  Thickness = 3.0151 µm
#  Diameter = 7.2840 µm
#  Outer Area = 9.0723 µm²
#  Inner Area = 0.6566 µm²
#  G-Ratio = 0.1721
#  Inner Contours = 1
#
# Axon 2 (regrowth_cluster):
#  Center = (4027.00, 3008.50)
#  Outer Radius = 3.7769 µm
#  Inner Radius = 1.7654 µm
#  Thickness = 2.0115 µm
#  Diameter = 7.5538 µm
#  Outer Area = 18.0059 µm²
#  Inner Area = 4.8460 µm²
#  G-Ratio = 0.4674
#  Inner Contours = 2
#
# Axon 3 (mature):
#  Center = (4070.00, 2927.50)
#  Outer Radius = 2.8177 µm
#  Inner Radius = 1.9825 µm
#  Thickness = 0.8352 µm
#  Diameter = 5.6354 µm
#  Outer Area = 17.0533 µm²
#  Inner Area = 4.8367 µm²
#  G-Ratio = 0.7036
#  Inner Contours = 1
#
# Axon 4 (mature):
#  Center = (4958.50, 3022.50)
#  Outer Radius = 2.1611 µm
#  Inner Radius = 0.9665 µm
#  Thickness = 1.1946 µm
#  Diameter = 4.3222 µm
#  Outer Area = 7.1764 µm²
#  Inner Area = 1.3410 µm²
#  G-Ratio = 0.4472
#  Inner Contours = 1
#
# Axon 5 (mature):
#  Center = (5062.19, 2990.86)
#  Outer Radius = 1.8399 µm
#  Inner Radius = 1.2050 µm
#  Thickness = 0.6349 µm
#  Diameter = 3.6798 µm
#  Outer Area = 8.2955 µm²
#  Inner Area = 2.6542 µm²
#  G-Ratio = 0.6549
#  Inner Contours = 1
#
# Axon 6 (mature):
#  Center = (5072.29, 2951.29)
#  Outer Radius = 2.0954 µm
#  Inner Radius = 1.3769 µm
#  Thickness = 0.7185 µm
#  Diameter = 4.1908 µm
#  Outer Area = 8.4249 µm²
#  Inner Area = 3.1258 µm²
#  G-Ratio = 0.6571
#  Inner Contours = 1
#
# Axon 7 (mature):
#  Center = (4887.49, 2852.36)
#  Outer Radius = 4.7330 µm
#  Inner Radius = 1.6447 µm
#  Thickness = 3.0883 µm
#  Diameter = 9.4661 µm
#  Outer Area = 52.4269 µm²
#  Inner Area = 5.1049 µm²
#  G-Ratio = 0.3475
#  Inner Contours = 1
#
# Axon 8 (mature):
#  Center = (4538.79, 2825.87)
#  Outer Radius = 2.7328 µm
#  Inner Radius = 1.9678 µm
#  Thickness = 0.7650 µm
#  Diameter = 5.4657 µm
#  Outer Area = 15.7586 µm²
#  Inner Area = 5.3823 µm²
#  G-Ratio = 0.7201
#  Inner Contours = 1
#
# Axon 9 (mature):
#  Center = (4779.67, 2833.39)
#  Outer Radius = 6.0659 µm
#  Inner Radius = 4.4758 µm
#  Thickness = 1.5901 µm
#  Diameter = 12.1318 µm
#  Outer Area = 94.6718 µm²
#  Inner Area = 34.1714 µm²
#  G-Ratio = 0.7379
#  Inner Contours = 1
#
# Axon 10 (mature):
#  Center = (4724.73, 2788.27)
#  Outer Radius = 1.4983 µm
#  Inner Radius = 1.1318 µm
#  Thickness = 0.3666 µm
#  Diameter = 2.9967 µm
#  Outer Area = 3.0333 µm²
#  Inner Area = 1.1652 µm²
#  G-Ratio = 0.7553
#  Inner Contours = 1
#
# Axon 11 (mature):
#  Center = (4889.50, 2787.00)
#  Outer Radius = 4.4720 µm
#  Inner Radius = 2.0411 µm
#  Thickness = 2.4309 µm
#  Diameter = 8.9440 µm
#  Outer Area = 40.4138 µm²
#  Inner Area = 9.4977 µm²
#  G-Ratio = 0.4564
#  Inner Contours = 1
#
# Axon 12 (regrowth_cluster):
#  Center = (4273.96, 2745.40)
#  Outer Radius = 3.6274 µm
#  Inner Radius = 2.9429 µm
#  Thickness = 0.6845 µm
#  Diameter = 7.2549 µm
#  Outer Area = 28.4191 µm²
#  Inner Area = 8.4619 µm²
#  G-Ratio = 0.8113
#  Inner Contours = 2
#
# Axon 13 (mature):
#  Center = (4372.01, 2752.75)
#  Outer Radius = 5.4521 µm
#  Inner Radius = 3.7894 µm
#  Thickness = 1.6627 µm
#  Diameter = 10.9042 µm
#  Outer Area = 75.4914 µm²
#  Inner Area = 27.8457 µm²
#  G-Ratio = 0.6950
#  Inner Contours = 1
#
# Axon 14 (mature):
#  Center = (5063.22, 2662.61)
#  Outer Radius = 2.4980 µm
#  Inner Radius = 1.5588 µm
#  Thickness = 0.9392 µm
#  Diameter = 4.9960 µm
#  Outer Area = 13.2616 µm²
#  Inner Area = 3.8657 µm²
#  G-Ratio = 0.6240
#  Inner Contours = 1
#
# Axon 15 (regrowth_cluster):
#  Center = (4884.04, 2663.42)
#  Outer Radius = 2.8236 µm
#  Inner Radius = 1.1256 µm
#  Thickness = 1.6980 µm
#  Diameter = 5.6471 µm
#  Outer Area = 14.5009 µm²
#  Inner Area = 2.1640 µm²
#  G-Ratio = 0.3986
#  Inner Contours = 2
#
# Axon 16 (regrowth_cluster):
#  Center = (4632.24, 2653.68)
#  Outer Radius = 2.9934 µm
#  Inner Radius = 1.7000 µm
#  Thickness = 1.2934 µm
#  Diameter = 5.9869 µm
#  Outer Area = 17.1920 µm²
#  Inner Area = 4.4575 µm²
#  G-Ratio = 0.5679
#  Inner Contours = 2
#
# Axon 17 (regrowth_cluster):
#  Center = (4167.56, 2648.50)
#  Outer Radius = 5.6852 µm
#  Inner Radius = 2.0000 µm
#  Thickness = 3.6853 µm
#  Diameter = 11.3705 µm
#  Outer Area = 39.7479 µm²
#  Inner Area = 7.8700 µm²
#  G-Ratio = 0.3518
#  Inner Contours = 2
#
# Axon 18 (mature):
#  Center = (5088.22, 2616.22)
#  Outer Radius = 3.9671 µm
#  Inner Radius = 0.7486 µm
#  Thickness = 3.2185 µm
#  Diameter = 7.9342 µm
#  Outer Area = 18.2833 µm²
#  Inner Area = 0.6844 µm²
#  G-Ratio = 0.1887
#  Inner Contours = 1
#
# Axon 19 (mature):
#  Center = (4456.76, 2592.70)
#  Outer Radius = 4.4623 µm
#  Inner Radius = 2.3788 µm
#  Thickness = 2.0835 µm
#  Diameter = 8.9246 µm
#  Outer Area = 45.3152 µm²
#  Inner Area = 11.8004 µm²
#  G-Ratio = 0.5331
#  Inner Contours = 1
#
# Axon 20 (mature):
#  Center = (4974.00, 2533.50)
#  Outer Radius = 3.0600 µm
#  Inner Radius = 2.0770 µm
#  Thickness = 0.9830 µm
#  Diameter = 6.1200 µm
#  Outer Area = 18.3388 µm²
#  Inner Area = 5.8725 µm²
#  G-Ratio = 0.6788
#  Inner Contours = 1
#
# Axon 21 (regrowth_cluster):
#  Center = (4522.51, 2511.49)
#  Outer Radius = 5.4453 µm
#  Inner Radius = 2.0592 µm
#  Thickness = 3.3861 µm
#  Diameter = 10.8907 µm
#  Outer Area = 65.6978 µm²
#  Inner Area = 7.1302 µm²
#  G-Ratio = 0.3782
#  Inner Contours = 2
#
# Axon 22 (regrowth_cluster):
#  Center = (4894.08, 2486.47)
#  Outer Radius = 4.2819 µm
#  Inner Radius = 2.4613 µm
#  Thickness = 1.8206 µm
#  Diameter = 8.5637 µm
#  Outer Area = 36.2429 µm²
#  Inner Area = 14.0292 µm²
#  G-Ratio = 0.5748
#  Inner Contours = 2
#
# Axon 23 (regrowth_cluster):
#  Center = (4682.00, 2407.00)
#  Outer Radius = 5.4553 µm
#  Inner Radius = 2.2679 µm
#  Thickness = 3.1873 µm
#  Diameter = 10.9106 µm
#  Outer Area = 38.6936 µm²
#  Inner Area = 11.8004 µm²
#  G-Ratio = 0.4157
#  Inner Contours = 3
#
# Axon 24 (mature):
#  Center = (5270.44, 3067.27)
#  Outer Radius = 4.7108 µm
#  Inner Radius = 2.0457 µm
#  Thickness = 2.6651 µm
#  Diameter = 9.4216 µm
#  Outer Area = 21.7328 µm²
#  Inner Area = 4.6517 µm²
#  G-Ratio = 0.4343
#  Inner Contours = 1
#
# Axon 25 (mature):
#  Center = (5169.50, 2972.50)
#  Outer Radius = 2.9248 µm
#  Inner Radius = 2.1513 µm
#  Thickness = 0.7735 µm
#  Diameter = 5.8496 µm
#  Outer Area = 18.7180 µm²
#  Inner Area = 8.7024 µm²
#  G-Ratio = 0.7355
#  Inner Contours = 1
#
# Axon 26 (mature):
#  Center = (5188.50, 2903.00)
#  Outer Radius = 2.9050 µm
#  Inner Radius = 1.3769 µm
#  Thickness = 1.5281 µm
#  Diameter = 5.8099 µm
#  Outer Area = 15.6476 µm²
#  Inner Area = 3.1073 µm²
#  G-Ratio = 0.4740
#  Inner Contours = 1
#
# Axon 27 (mature):
#  Center = (5151.50, 2861.50)
#  Outer Radius = 2.2859 µm
#  Inner Radius = 1.1911 µm
#  Thickness = 1.0948 µm
#  Diameter = 4.5717 µm
#  Outer Area = 9.8861 µm²
#  Inner Area = 2.5524 µm²
#  G-Ratio = 0.5211
#  Inner Contours = 1
#
# Axon 28 (mature):
#  Center = (5581.22, 2840.05)
#  Outer Radius = 3.4544 µm
#  Inner Radius = 2.4271 µm
#  Thickness = 1.0273 µm
#  Diameter = 6.9089 µm
#  Outer Area = 23.9061 µm²
#  Inner Area = 8.9058 µm²
#  G-Ratio = 0.7026
#  Inner Contours = 1
#
# Axon 29 (mature):
#  Center = (5266.50, 2834.00)
#  Outer Radius = 2.8210 µm
#  Inner Radius = 0.9249 µm
#  Thickness = 1.8961 µm
#  Diameter = 5.6420 µm
#  Outer Area = 10.0526 µm²
#  Inner Area = 1.5352 µm²
#  G-Ratio = 0.3279
#  Inner Contours = 1
#
# Axon 30 (regrowth_cluster):
#  Center = (5308.66, 2806.00)
#  Outer Radius = 3.5131 µm
#  Inner Radius = 2.4356 µm
#  Thickness = 1.0775 µm
#  Diameter = 7.0262 µm
#  Outer Area = 26.7360 µm²
#  Inner Area = 12.9380 µm²
#  G-Ratio = 0.6933
#  Inner Contours = 2
#
# Axon 31 (mature):
#  Center = (5373.50, 2765.50)
#  Outer Radius = 3.0908 µm
#  Inner Radius = 2.5055 µm
#  Thickness = 0.5854 µm
#  Diameter = 6.1817 µm
#  Outer Area = 22.9073 µm²
#  Inner Area = 12.3183 µm²
#  G-Ratio = 0.8106
#  Inner Contours = 1
#
# Axon 32 (mature):
#  Center = (5136.05, 2756.01)
#  Outer Radius = 2.4565 µm
#  Inner Radius = 1.1816 µm
#  Thickness = 1.2749 µm
#  Diameter = 4.9130 µm
#  Outer Area = 10.5335 µm²
#  Inner Area = 2.6264 µm²
#  G-Ratio = 0.4810
#  Inner Contours = 1
#
# Axon 33 (mature):
#  Center = (5254.63, 2758.70)
#  Outer Radius = 5.2256 µm
#  Inner Radius = 3.3713 µm
#  Thickness = 1.8542 µm
#  Diameter = 10.4512 µm
#  Outer Area = 66.5024 µm²
#  Inner Area = 15.9898 µm²
#  G-Ratio = 0.6452
#  Inner Contours = 1
#
# Axon 34 (mature):
#  Center = (5543.50, 2713.00)
#  Outer Radius = 3.3843 µm
#  Inner Radius = 1.5342 µm
#  Thickness = 1.8502 µm
#  Diameter = 6.7687 µm
#  Outer Area = 10.3670 µm²
#  Inner Area = 3.7454 µm²
#  G-Ratio = 0.4533
#  Inner Contours = 1
#
# Axon 35 (regrowth_cluster):
#  Center = (5301.50, 2689.50)
#  Outer Radius = 2.6598 µm
#  Inner Radius = 1.1036 µm
#  Thickness = 1.5562 µm
#  Diameter = 5.3197 µm
#  Outer Area = 12.3646 µm²
#  Inner Area = 1.9976 µm²
#  G-Ratio = 0.4149
#  Inner Contours = 2
#
# Axon 36 (mature):
#  Center = (5176.00, 2656.67)
#  Outer Radius = 4.0863 µm
#  Inner Radius = 1.3896 µm
#  Thickness = 2.6967 µm
#  Diameter = 8.1726 µm
#  Outer Area = 25.0898 µm²
#  Inner Area = 2.6727 µm²
#  G-Ratio = 0.3401
#  Inner Contours = 1
#
# Axon 37 (mature):
#  Center = (5402.30, 2619.34)
#  Outer Radius = 5.7937 µm
#  Inner Radius = 3.5720 µm
#  Thickness = 2.2217 µm
#  Diameter = 11.5873 µm
#  Outer Area = 81.5766 µm²
#  Inner Area = 19.3376 µm²
#  G-Ratio = 0.6165
#  Inner Contours = 1
#
# Axon 38 (mature):
#  Center = (5336.58, 2523.58)
#  Outer Radius = 3.0784 µm
#  Inner Radius = 1.3329 µm
#  Thickness = 1.7455 µm
#  Diameter = 6.1568 µm
#  Outer Area = 18.8474 µm²
#  Inner Area = 4.0414 µm²
#  G-Ratio = 0.4330
#  Inner Contours = 1
#
# Axon 39 (regrowth_cluster):
#  Center = (5262.62, 2523.47)
#  Outer Radius = 3.1852 µm
#  Inner Radius = 1.3769 µm
#  Thickness = 1.8083 µm
#  Diameter = 6.3704 µm
#  Outer Area = 20.0312 µm²
#  Inner Area = 2.7467 µm²
#  G-Ratio = 0.4323
#  Inner Contours = 2
#
# Axon 40 (mature):
#  Center = (5158.64, 2437.90)
#  Outer Radius = 3.0712 µm
#  Inner Radius = 1.3935 µm
#  Thickness = 1.6778 µm
#  Diameter = 6.1425 µm
#  Outer Area = 17.2568 µm²
#  Inner Area = 3.8657 µm²
#  G-Ratio = 0.4537
#  Inner Contours = 1
#
# Axon 41 (mature):
#  Center = (4047.39, 3745.73)
#  Outer Radius = 1.8314 µm
#  Inner Radius = 1.2834 µm
#  Thickness = 0.5480 µm
#  Diameter = 3.6628 µm
#  Outer Area = 6.2516 µm²
#  Inner Area = 2.5802 µm²
#  G-Ratio = 0.7008
#  Inner Contours = 1
#
# Axon 42 (mature):
#  Center = (4038.50, 3229.00)
#  Outer Radius = 4.1835 µm
#  Inner Radius = 1.6795 µm
#  Thickness = 2.5040 µm
#  Diameter = 8.3671 µm
#  Outer Area = 15.5736 µm²
#  Inner Area = 3.7177 µm²
#  G-Ratio = 0.4015
#  Inner Contours = 1
#
# Axon 43 (mature):
#  Center = (4766.00, 4087.00)
#  Outer Radius = 2.7098 µm
#  Inner Radius = 0.5753 µm
#  Thickness = 2.1345 µm
#  Diameter = 5.4196 µm
#  Outer Area = 8.3879 µm²
#  Inner Area = 0.6104 µm²
#  G-Ratio = 0.2123
#  Inner Contours = 1
#
# Axon 44 (mature):
#  Center = (4947.50, 4087.50)
#  Outer Radius = 4.6170 µm
#  Inner Radius = 0.8871 µm
#  Thickness = 3.7299 µm
#  Diameter = 9.2340 µm
#  Outer Area = 17.0441 µm²
#  Inner Area = 1.4982 µm²
#  G-Ratio = 0.1921
#  Inner Contours = 1
#
# Axon 45 (mature):
#  Center = (4180.00, 3922.50)
#  Outer Radius = 2.5489 µm
#  Inner Radius = 0.6834 µm
#  Thickness = 1.8655 µm
#  Diameter = 5.0978 µm
#  Outer Area = 6.4551 µm²
#  Inner Area = 0.5826 µm²
#  G-Ratio = 0.2681
#  Inner Contours = 1
#
# Axon 46 (mature):
#  Center = (4823.50, 3913.50)
#  Outer Radius = 2.9500 µm
#  Inner Radius = 1.7062 µm
#  Thickness = 1.2437 µm
#  Diameter = 5.9000 µm
#  Outer Area = 10.3115 µm²
#  Inner Area = 4.6055 µm²
#  G-Ratio = 0.5784
#  Inner Contours = 1
#
# Axon 47 (regrowth_cluster):
#  Center = (4873.17, 3893.22)
#  Outer Radius = 2.9934 µm
#  Inner Radius = 1.5875 µm
#  Thickness = 1.4059 µm
#  Diameter = 5.9869 µm
#  Outer Area = 20.9560 µm²
#  Inner Area = 3.1073 µm²
#  G-Ratio = 0.5303
#  Inner Contours = 3
#
# Axon 48 (regrowth_cluster):
#  Center = (4257.69, 3834.44)
#  Outer Radius = 3.1055 µm
#  Inner Radius = 1.8762 µm
#  Thickness = 1.2293 µm
#  Diameter = 6.2110 µm
#  Outer Area = 17.1273 µm²
#  Inner Area = 3.8472 µm²
#  G-Ratio = 0.6042
#  Inner Contours = 2
#
# Axon 49 (mature):
#  Center = (4801.35, 3851.72)
#  Outer Radius = 6.6604 µm
#  Inner Radius = 3.2942 µm
#  Thickness = 3.3663 µm
#  Diameter = 13.3209 µm
#  Outer Area = 97.4832 µm²
#  Inner Area = 25.7834 µm²
#  G-Ratio = 0.4946
#  Inner Contours = 1
#
# Axon 50 (mature):
#  Center = (4118.04, 3803.04)
#  Outer Radius = 3.2914 µm
#  Inner Radius = 2.8300 µm
#  Thickness = 0.4614 µm
#  Diameter = 6.5827 µm
#  Outer Area = 18.2925 µm²
#  Inner Area = 4.1893 µm²
#  G-Ratio = 0.8598
#  Inner Contours = 1
#
# Axon 51 (mature):
#  Center = (4996.51, 3757.47)
#  Outer Radius = 3.0773 µm
#  Inner Radius = 0.9123 µm
#  Thickness = 2.1650 µm
#  Diameter = 6.1546 µm
#  Outer Area = 16.6279 µm²
#  Inner Area = 1.3595 µm²
#  G-Ratio = 0.2965
#  Inner Contours = 1
#
# Axon 52 (mature):
#  Center = (4308.50, 3720.00)
#  Outer Radius = 3.2957 µm
#  Inner Radius = 2.1504 µm
#  Thickness = 1.1454 µm
#  Diameter = 6.5915 µm
#  Outer Area = 25.0528 µm²
#  Inner Area = 8.7486 µm²
#  G-Ratio = 0.6525
#  Inner Contours = 1
#
# Axon 53 (regrowth_cluster):
#  Center = (4395.77, 3703.82)
#  Outer Radius = 3.0324 µm
#  Inner Radius = 1.2012 µm
#  Thickness = 1.8311 µm
#  Diameter = 6.0647 µm
#  Outer Area = 18.6162 µm²
#  Inner Area = 2.9594 µm²
#  G-Ratio = 0.3961
#  Inner Contours = 2
#
# Axon 54 (mature):
#  Center = (4620.00, 3808.00)
#  Outer Radius = 17.4510 µm
#  Inner Radius = 1.3876 µm
#  Thickness = 16.0634 µm
#  Diameter = 34.9020 µm
#  Outer Area = 208.4499 µm²
#  Inner Area = 3.8009 µm²
#  G-Ratio = 0.0795
#  Inner Contours = 1
#
# Axon 55 (mature):
#  Center = (4823.00, 3696.50)
#  Outer Radius = 3.2676 µm
#  Inner Radius = 1.4822 µm
#  Thickness = 1.7854 µm
#  Diameter = 6.5351 µm
#  Outer Area = 17.7284 µm²
#  Inner Area = 4.3928 µm²
#  G-Ratio = 0.4536
#  Inner Contours = 1
#
# Axon 56 (mature):
#  Center = (4701.09, 3691.09)
#  Outer Radius = 2.8927 µm
#  Inner Radius = 1.0752 µm
#  Thickness = 1.8175 µm
#  Diameter = 5.7853 µm
#  Outer Area = 12.5403 µm²
#  Inner Area = 1.4797 µm²
#  G-Ratio = 0.3717
#  Inner Contours = 1
#
# Axon 57 (mature):
#  Center = (4530.25, 3870.78)
#  Outer Radius = 28.6618 µm
#  Inner Radius = 3.3202 µm
#  Thickness = 25.3416 µm
#  Diameter = 57.3236 µm
#  Outer Area = 859.9438 µm²
#  Inner Area = 6.2701 µm²
#  G-Ratio = 0.1158
#  Inner Contours = 1
#
# Axon 58 (mature):
#  Center = (4804.00, 3659.00)
#  Outer Radius = 2.1929 µm
#  Inner Radius = 1.5699 µm
#  Thickness = 0.6230 µm
#  Diameter = 4.3859 µm
#  Outer Area = 8.6839 µm²
#  Inner Area = 3.5142 µm²
#  G-Ratio = 0.7159
#  Inner Contours = 1
#
# Axon 59 (regrowth_cluster):
#  Center = (4393.87, 3657.28)
#  Outer Radius = 3.1380 µm
#  Inner Radius = 1.9996 µm
#  Thickness = 1.1384 µm
#  Diameter = 6.2760 µm
#  Outer Area = 21.8715 µm²
#  Inner Area = 5.7800 µm²
#  G-Ratio = 0.6372
#  Inner Contours = 2
#
# Axon 60 (mature):
#  Center = (4980.50, 3630.00)
#  Outer Radius = 6.0886 µm
#  Inner Radius = 4.3465 µm
#  Thickness = 1.7421 µm
#  Diameter = 12.1772 µm
#  Outer Area = 79.1721 µm²
#  Inner Area = 32.2015 µm²
#  G-Ratio = 0.7139
#  Inner Contours = 1
#
# Axon 61 (mature):
#  Center = (4420.00, 3596.50)
#  Outer Radius = 1.4852 µm
#  Inner Radius = 0.6196 µm
#  Thickness = 0.8656 µm
#  Diameter = 2.9703 µm
#  Outer Area = 4.4853 µm²
#  Inner Area = 0.6196 µm²
#  G-Ratio = 0.4172
#  Inner Contours = 1
#
# Axon 62 (regrowth_cluster):
#  Center = (4475.00, 3620.50)
#  Outer Radius = 5.7800 µm
#  Inner Radius = 3.6777 µm
#  Thickness = 2.1023 µm
#  Diameter = 11.5600 µm
#  Outer Area = 58.4289 µm²
#  Inner Area = 13.3726 µm²
#  G-Ratio = 0.6363
#  Inner Contours = 4
#
# Axon 63 (mature):
#  Center = (4559.35, 3591.19)
#  Outer Radius = 3.0481 µm
#  Inner Radius = 1.3482 µm
#  Thickness = 1.6999 µm
#  Diameter = 6.0961 µm
#  Outer Area = 13.3819 µm²
#  Inner Area = 4.2078 µm²
#  G-Ratio = 0.4423
#  Inner Contours = 1
#
# Axon 64 (mature):
#  Center = (4662.50, 3585.50)
#  Outer Radius = 3.4740 µm
#  Inner Radius = 2.3605 µm
#  Thickness = 1.1135 µm
#  Diameter = 6.9480 µm
#  Outer Area = 25.1361 µm²
#  Inner Area = 8.6006 µm²
#  G-Ratio = 0.6795
#  Inner Contours = 1
#
# Axon 65 (mature):
#  Center = (5058.31, 3574.46)
#  Outer Radius = 2.5173 µm
#  Inner Radius = 1.8823 µm
#  Thickness = 0.6350 µm
#  Diameter = 5.0347 µm
#  Outer Area = 13.7703 µm²
#  Inner Area = 5.9280 µm²
#  G-Ratio = 0.7477
#  Inner Contours = 1
#
# Axon 66 (mature):
#  Center = (4987.00, 3497.00)
#  Outer Radius = 3.3590 µm
#  Inner Radius = 1.6795 µm
#  Thickness = 1.6795 µm
#  Diameter = 6.7179 µm
#  Outer Area = 16.5724 µm²
#  Inner Area = 3.3755 µm²
#  G-Ratio = 0.5000
#  Inner Contours = 1
#
# Axon 67 (mature):
#  Center = (4287.12, 3484.77)
#  Outer Radius = 2.6511 µm
#  Inner Radius = 1.0965 µm
#  Thickness = 1.5546 µm
#  Diameter = 5.3021 µm
#  Outer Area = 14.5748 µm²
#  Inner Area = 1.7664 µm²
#  G-Ratio = 0.4136
#  Inner Contours = 1
#
# Axon 68 (regrowth_cluster):
#  Center = (4478.51, 3471.83)
#  Outer Radius = 3.3616 µm
#  Inner Radius = 1.7041 µm
#  Thickness = 1.6575 µm
#  Diameter = 6.7231 µm
#  Outer Area = 15.0835 µm²
#  Inner Area = 4.0784 µm²
#  G-Ratio = 0.5069
#  Inner Contours = 2
#
# Axon 69 (mature):
#  Center = (4422.55, 3455.96)
#  Outer Radius = 4.5794 µm
#  Inner Radius = 2.7955 µm
#  Thickness = 1.7839 µm
#  Diameter = 9.1588 µm
#  Outer Area = 53.0280 µm²
#  Inner Area = 18.8659 µm²
#  G-Ratio = 0.6104
#  Inner Contours = 1
#
# Axon 70 (regrowth_cluster):
#  Center = (4173.00, 3436.00)
#  Outer Radius = 3.4833 µm
#  Inner Radius = 1.6545 µm
#  Thickness = 1.8288 µm
#  Diameter = 6.9666 µm
#  Outer Area = 18.8012 µm²
#  Inner Area = 3.8009 µm²
#  G-Ratio = 0.4750
#  Inner Contours = 2
#
# Axon 71 (regrowth_cluster):
#  Center = (4592.61, 3449.62)
#  Outer Radius = 5.2672 µm
#  Inner Radius = 2.8858 µm
#  Thickness = 2.3814 µm
#  Diameter = 10.5345 µm
#  Outer Area = 69.8316 µm²
#  Inner Area = 12.3646 µm²
#  G-Ratio = 0.5479
#  Inner Contours = 2
#
# Axon 72 (regrowth_cluster):
#  Center = (4992.08, 3435.96)
#  Outer Radius = 3.6637 µm
#  Inner Radius = 1.7549 µm
#  Thickness = 1.9088 µm
#  Diameter = 7.3274 µm
#  Outer Area = 31.3507 µm²
#  Inner Area = 7.6019 µm²
#  G-Ratio = 0.4790
#  Inner Contours = 2
#
# Axon 73 (mature):
#  Center = (4932.40, 3445.15)
#  Outer Radius = 6.2114 µm
#  Inner Radius = 3.8529 µm
#  Thickness = 2.3585 µm
#  Diameter = 12.4227 µm
#  Outer Area = 88.6976 µm²
#  Inner Area = 29.4919 µm²
#  G-Ratio = 0.6203
#  Inner Contours = 1
#
# Axon 74 (mature):
#  Center = (4361.31, 3398.66)
#  Outer Radius = 5.9078 µm
#  Inner Radius = 4.0414 µm
#  Thickness = 1.8664 µm
#  Diameter = 11.8155 µm
#  Outer Area = 83.7129 µm²
#  Inner Area = 26.7730 µm²
#  G-Ratio = 0.6841
#  Inner Contours = 1
#
# Axon 75 (regrowth_cluster):
#  Center = (4563.99, 3364.92)
#  Outer Radius = 3.8594 µm
#  Inner Radius = 1.9052 µm
#  Thickness = 1.9541 µm
#  Diameter = 7.7187 µm
#  Outer Area = 24.7939 µm²
#  Inner Area = 5.0309 µm²
#  G-Ratio = 0.4937
#  Inner Contours = 3
#
# Axon 76 (mature):
#  Center = (4509.89, 3355.11)
#  Outer Radius = 2.5709 µm
#  Inner Radius = 1.7203 µm
#  Thickness = 0.8507 µm
#  Diameter = 5.1419 µm
#  Outer Area = 14.0200 µm²
#  Inner Area = 4.7812 µm²
#  G-Ratio = 0.6691
#  Inner Contours = 1
#
# Axon 77 (mature):
#  Center = (4470.50, 3336.00)
#  Outer Radius = 2.3916 µm
#  Inner Radius = 1.7484 µm
#  Thickness = 0.6433 µm
#  Diameter = 4.7833 µm
#  Outer Area = 13.3356 µm²
#  Inner Area = 5.5396 µm²
#  G-Ratio = 0.7310
#  Inner Contours = 1
#
# Axon 78 (mature):
#  Center = (4461.51, 3167.05)
#  Outer Radius = 3.5318 µm
#  Inner Radius = 1.1580 µm
#  Thickness = 2.3738 µm
#  Diameter = 7.0636 µm
#  Outer Area = 17.3585 µm²
#  Inner Area = 1.4889 µm²
#  G-Ratio = 0.3279
#  Inner Contours = 1
#
# Axon 79 (regrowth_cluster):
#  Center = (5513.40, 4040.70)
#  Outer Radius = 7.7251 µm
#  Inner Radius = 2.5243 µm
#  Thickness = 5.2008 µm
#  Diameter = 15.4501 µm
#  Outer Area = 102.6620 µm²
#  Inner Area = 7.9440 µm²
#  G-Ratio = 0.3268
#  Inner Contours = 6
#
# Axon 80 (mature):
#  Center = (5139.00, 3917.95)
#  Outer Radius = 3.1472 µm
#  Inner Radius = 0.8411 µm
#  Thickness = 2.3061 µm
#  Diameter = 6.2944 µm
#  Outer Area = 8.6839 µm²
#  Inner Area = 1.1283 µm²
#  G-Ratio = 0.2673
#  Inner Contours = 1
#
# Axon 81 (mature):
#  Center = (5545.50, 3826.00)
#  Outer Radius = 4.1167 µm
#  Inner Radius = 2.7548 µm
#  Thickness = 1.3619 µm
#  Diameter = 8.2334 µm
#  Outer Area = 35.3921 µm²
#  Inner Area = 13.8997 µm²
#  G-Ratio = 0.6692
#  Inner Contours = 1
#
# Axon 82 (mature):
#  Center = (5434.33, 3789.69)
#  Outer Radius = 2.5123 µm
#  Inner Radius = 1.7337 µm
#  Thickness = 0.7787 µm
#  Diameter = 5.0247 µm
#  Outer Area = 12.9102 µm²
#  Inner Area = 4.8182 µm²
#  G-Ratio = 0.6901
#  Inner Contours = 1
#
# Axon 83 (regrowth_cluster):
#  Center = (5652.00, 3776.00)
#  Outer Radius = 3.9651 µm
#  Inner Radius = 2.2531 µm
#  Thickness = 1.7120 µm
#  Diameter = 7.9301 µm
#  Outer Area = 27.0227 µm²
#  Inner Area = 7.8516 µm²
#  G-Ratio = 0.5682
#  Inner Contours = 2
#
# Axon 84 (mature):
#  Center = (5493.07, 3683.21)
#  Outer Radius = 3.3947 µm
#  Inner Radius = 2.5876 µm
#  Thickness = 0.8071 µm
#  Diameter = 6.7893 µm
#  Outer Area = 26.7545 µm²
#  Inner Area = 11.2918 µm²
#  G-Ratio = 0.7623
#  Inner Contours = 1
#
# Axon 85 (mature):
#  Center = (5266.84, 3654.16)
#  Outer Radius = 1.9219 µm
#  Inner Radius = 1.1225 µm
#  Thickness = 0.7994 µm
#  Diameter = 3.8439 µm
#  Outer Area = 6.5476 µm²
#  Inner Area = 2.0531 µm²
#  G-Ratio = 0.5841
#  Inner Contours = 1
#
# Axon 86 (mature):
#  Center = (5555.50, 3625.50)
#  Outer Radius = 3.7009 µm
#  Inner Radius = 1.0109 µm
#  Thickness = 2.6900 µm
#  Diameter = 7.4017 µm
#  Outer Area = 18.1908 µm²
#  Inner Area = 1.4612 µm²
#  G-Ratio = 0.2732
#  Inner Contours = 1
#
# Axon 87 (mature):
#  Center = (5300.00, 3590.50)
#  Outer Radius = 5.6046 µm
#  Inner Radius = 3.4434 µm
#  Thickness = 2.1612 µm
#  Diameter = 11.2091 µm
#  Outer Area = 75.0290 µm²
#  Inner Area = 21.7790 µm²
#  G-Ratio = 0.6144
#  Inner Contours = 1
#
# Axon 88 (mature):
#  Center = (5735.50, 3542.00)
#  Outer Radius = 1.6221 µm
#  Inner Radius = 0.9665 µm
#  Thickness = 0.6556 µm
#  Diameter = 3.2441 µm
#  Outer Area = 5.9557 µm²
#  Inner Area = 1.7849 µm²
#  G-Ratio = 0.5958
#  Inner Contours = 1
#
# Axon 89 (mature):
#  Center = (5638.20, 3548.25)
#  Outer Radius = 3.2291 µm
#  Inner Radius = 2.6160 µm
#  Thickness = 0.6131 µm
#  Diameter = 6.4582 µm
#  Outer Area = 19.8462 µm²
#  Inner Area = 8.2400 µm²
#  G-Ratio = 0.8101
#  Inner Contours = 1
#
# Axon 90 (regrowth_cluster):
#  Center = (5212.36, 3421.44)
#  Outer Radius = 3.1327 µm
#  Inner Radius = 1.1986 µm
#  Thickness = 1.9342 µm
#  Diameter = 6.2655 µm
#  Outer Area = 13.8812 µm²
#  Inner Area = 2.8114 µm²
#  G-Ratio = 0.3826
#  Inner Contours = 2
#
# Axon 91 (regrowth_cluster):
#  Center = (5685.12, 3402.16)
#  Outer Radius = 2.8937 µm
#  Inner Radius = 1.0752 µm
#  Thickness = 1.8185 µm
#  Diameter = 5.7874 µm
#  Outer Area = 18.8104 µm²
#  Inner Area = 1.9421 µm²
#  G-Ratio = 0.3716
#  Inner Contours = 2
#
# Axon 92 (mature):
#  Center = (5762.00, 3388.50)
#  Outer Radius = 3.1199 µm
#  Inner Radius = 1.9411 µm
#  Thickness = 1.1787 µm
#  Diameter = 6.2397 µm
#  Outer Area = 21.2704 µm²
#  Inner Area = 5.5396 µm²
#  G-Ratio = 0.6222
#  Inner Contours = 1
#
# Axon 93 (mature):
#  Center = (5137.99, 3353.35)
#  Outer Radius = 3.1289 µm
#  Inner Radius = 2.3808 µm
#  Thickness = 0.7481 µm
#  Diameter = 6.2578 µm
#  Outer Area = 21.8253 µm²
#  Inner Area = 10.3300 µm²
#  G-Ratio = 0.7609
#  Inner Contours = 1
#
# Axon 94 (regrowth_cluster):
#  Center = (5268.64, 3078.38)
#  Outer Radius = 4.7528 µm
#  Inner Radius = 1.5507 µm
#  Thickness = 3.2021 µm
#  Diameter = 9.5056 µm
#  Outer Area = 29.3809 µm²
#  Inner Area = 3.6437 µm²
#  G-Ratio = 0.3263
#  Inner Contours = 2
#
# Axon 95 (mature):
#  Center = (6410.61, 4063.71)
#  Outer Radius = 3.1646 µm
#  Inner Radius = 2.1504 µm
#  Thickness = 1.0142 µm
#  Diameter = 6.3292 µm
#  Outer Area = 23.0183 µm²
#  Inner Area = 6.5291 µm²
#  G-Ratio = 0.6795
#  Inner Contours = 1
#
# Axon 96 (mature):
#  Center = (7093.50, 4064.00)
#  Outer Radius = 6.3079 µm
#  Inner Radius = 3.0877 µm
#  Thickness = 3.2202 µm
#  Diameter = 12.6158 µm
#  Outer Area = 83.8979 µm²
#  Inner Area = 24.1928 µm²
#  G-Ratio = 0.4895
#  Inner Contours = 1
#
# Axon 97 (mature):
#  Center = (7061.00, 3965.50)
#  Outer Radius = 7.0291 µm
#  Inner Radius = 4.6784 µm
#  Thickness = 2.3507 µm
#  Diameter = 14.0581 µm
#  Outer Area = 106.7774 µm²
#  Inner Area = 41.0056 µm²
#  G-Ratio = 0.6656
#  Inner Contours = 1
#
# Axon 98 (mature):
#  Center = (6762.00, 3938.00)
#  Outer Radius = 4.7600 µm
#  Inner Radius = 0.9743 µm
#  Thickness = 3.7858 µm
#  Diameter = 9.5200 µm
#  Outer Area = 22.0842 µm²
#  Inner Area = 2.1270 µm²
#  G-Ratio = 0.2047
#  Inner Contours = 1
#
# Axon 99 (regrowth_cluster):
#  Center = (6877.50, 3917.50)
#  Outer Radius = 3.2824 µm
#  Inner Radius = 1.0529 µm
#  Thickness = 2.2294 µm
#  Diameter = 6.5648 µm
#  Outer Area = 15.2592 µm²
#  Inner Area = 2.0346 µm²
#  G-Ratio = 0.3208
#  Inner Contours = 2
#
# Axon 100 (mature):
#  Center = (4862.07, 4563.11)
#  Outer Radius = 5.9429 µm
#  Inner Radius = 4.2932 µm
#  Thickness = 1.6497 µm
#  Diameter = 11.8858 µm
#  Outer Area = 84.8227 µm²
#  Inner Area = 35.1239 µm²
#  G-Ratio = 0.7224
#  Inner Contours = 1
#
# Axon 101 (mature):
#  Center = (4567.50, 4509.50)
#  Outer Radius = 3.0182 µm
#  Inner Radius = 1.9233 µm
#  Thickness = 1.0948 µm
#  Diameter = 6.0363 µm
#  Outer Area = 14.4454 µm²
#  Inner Area = 3.0796 µm²
#  G-Ratio = 0.6373
#  Inner Contours = 1
#
# Axon 102 (mature):
#  Center = (4770.42, 4436.40)
#  Outer Radius = 5.7724 µm
#  Inner Radius = 3.9240 µm
#  Thickness = 1.8484 µm
#  Diameter = 11.5448 µm
#  Outer Area = 84.4527 µm²
#  Inner Area = 37.7688 µm²
#  G-Ratio = 0.6798
#  Inner Contours = 1
#
# Axon 103 (mature):
#  Center = (4686.00, 4363.50)
#  Outer Radius = 5.2624 µm
#  Inner Radius = 2.9588 µm
#  Thickness = 2.3036 µm
#  Diameter = 10.5249 µm
#  Outer Area = 54.6279 µm²
#  Inner Area = 14.2049 µm²
#  G-Ratio = 0.5623
#  Inner Contours = 1
#
# Axon 104 (mature):
#  Center = (4868.00, 4337.50)
#  Outer Radius = 4.3610 µm
#  Inner Radius = 2.9295 µm
#  Thickness = 1.4315 µm
#  Diameter = 8.7221 µm
#  Outer Area = 48.3023 µm²
#  Inner Area = 18.2463 µm²
#  G-Ratio = 0.6718
#  Inner Contours = 1
#
# Axon 105 (mature):
#  Center = (4380.55, 4277.93)
#  Outer Radius = 1.9883 µm
#  Inner Radius = 0.7753 µm
#  Thickness = 1.2130 µm
#  Diameter = 3.9766 µm
#  Outer Area = 5.5673 µm²
#  Inner Area = 0.9895 µm²
#  G-Ratio = 0.3900
#  Inner Contours = 1
#
# Axon 106 (mature):
#  Center = (4920.97, 4236.29)
#  Outer Radius = 2.2171 µm
#  Inner Radius = 1.5405 µm
#  Thickness = 0.6766 µm
#  Diameter = 4.4341 µm
#  Outer Area = 12.3923 µm²
#  Inner Area = 4.4853 µm²
#  G-Ratio = 0.6948
#  Inner Contours = 1
#
# Axon 107 (regrowth_cluster):
#  Center = (4593.00, 4173.50)
#  Outer Radius = 2.9050 µm
#  Inner Radius = 1.0554 µm
#  Thickness = 1.8496 µm
#  Diameter = 5.8099 µm
#  Outer Area = 11.7172 µm²
#  Inner Area = 2.4877 µm²
#  G-Ratio = 0.3633
#  Inner Contours = 2
#
# Axon 108 (mature):
#  Center = (4283.00, 4128.00)
#  Outer Radius = 3.1750 µm
#  Inner Radius = 2.3477 µm
#  Thickness = 0.8272 µm
#  Diameter = 6.3499 µm
#  Outer Area = 21.1039 µm²
#  Inner Area = 5.3084 µm²
#  G-Ratio = 0.7395
#  Inner Contours = 1
#
# Axon 109 (mature):
#  Center = (5268.50, 4405.30)
#  Outer Radius = 2.5658 µm
#  Inner Radius = 1.5066 µm
#  Thickness = 1.0592 µm
#  Diameter = 5.1317 µm
#  Outer Area = 12.6143 µm²
#  Inner Area = 3.3385 µm²
#  G-Ratio = 0.5872
#  Inner Contours = 1
#
# Axon 110 (mature):
#  Center = (5176.50, 4321.00)
#  Outer Radius = 4.8681 µm
#  Inner Radius = 3.1866 µm
#  Thickness = 1.6815 µm
#  Diameter = 9.7361 µm
#  Outer Area = 50.5681 µm²
#  Inner Area = 17.8024 µm²
#  G-Ratio = 0.6546
#  Inner Contours = 1
#
# Axon 111 (mature):
#  Center = (7039.50, 5015.50)
#  Outer Radius = 2.0286 µm
#  Inner Radius = 1.3600 µm
#  Thickness = 0.6686 µm
#  Diameter = 4.0573 µm
#  Outer Area = 6.0759 µm²
#  Inner Area = 2.1178 µm²
#  G-Ratio = 0.6704
#  Inner Contours = 1
#
# Axon 112 (regrowth_cluster):
#  Center = (6936.00, 5042.50)
#  Outer Radius = 9.5484 µm
#  Inner Radius = 3.7400 µm
#  Thickness = 5.8084 µm
#  Diameter = 19.0968 µm
#  Outer Area = 89.0860 µm²
#  Inner Area = 22.3524 µm²
#  G-Ratio = 0.3917
#  Inner Contours = 2
#
# Axon 113 (mature):
#  Center = (7107.50, 5009.00)
#  Outer Radius = 3.7027 µm
#  Inner Radius = 2.1179 µm
#  Thickness = 1.5849 µm
#  Diameter = 7.4055 µm
#  Outer Area = 18.3480 µm²
#  Inner Area = 4.0876 µm²
#  G-Ratio = 0.5720
#  Inner Contours = 1
#
# Axon 114 (mature):
#  Center = (7059.50, 4959.00)
#  Outer Radius = 3.2845 µm
#  Inner Radius = 0.8411 µm
#  Thickness = 2.4434 µm
#  Diameter = 6.5690 µm
#  Outer Area = 10.6352 µm²
#  Inner Area = 1.3964 µm²
#  G-Ratio = 0.2561
#  Inner Contours = 1
#
# Axon 115 (mature):
#  Center = (6556.50, 4944.00)
#  Outer Radius = 4.1413 µm
#  Inner Radius = 1.4345 µm
#  Thickness = 2.7068 µm
#  Diameter = 8.2826 µm
#  Outer Area = 17.4695 µm²
#  Inner Area = 2.1548 µm²
#  G-Ratio = 0.3464
#  Inner Contours = 1
#
# Axon 116 (regrowth_cluster):
#  Center = (6972.60, 4924.20)
#  Outer Radius = 3.8797 µm
#  Inner Radius = 1.6188 µm
#  Thickness = 2.2609 µm
#  Diameter = 7.7594 µm
#  Outer Area = 31.4524 µm²
#  Inner Area = 4.2448 µm²
#  G-Ratio = 0.4172
#  Inner Contours = 2
#
# Axon 117 (mature):
#  Center = (7058.12, 4912.86)
#  Outer Radius = 2.6167 µm
#  Inner Radius = 1.5819 µm
#  Thickness = 1.0348 µm
#  Diameter = 5.2333 µm
#  Outer Area = 15.9343 µm²
#  Inner Area = 5.4563 µm²
#  G-Ratio = 0.6045
#  Inner Contours = 1
#
# Axon 118 (regrowth_cluster):
#  Center = (7006.84, 4857.62)
#  Outer Radius = 5.0874 µm
#  Inner Radius = 2.3605 µm
#  Thickness = 2.7269 µm
#  Diameter = 10.1748 µm
#  Outer Area = 38.4069 µm²
#  Inner Area = 9.9139 µm²
#  G-Ratio = 0.4640
#  Inner Contours = 3
#
# Axon 119 (mature):
#  Center = (7038.50, 4781.00)
#  Outer Radius = 3.5834 µm
#  Inner Radius = 2.6487 µm
#  Thickness = 0.9347 µm
#  Diameter = 7.1669 µm
#  Outer Area = 19.3098 µm²
#  Inner Area = 8.5267 µm²
#  G-Ratio = 0.7392
#  Inner Contours = 1
#
# Axon 120 (mature):
#  Center = (7138.50, 4770.00)
#  Outer Radius = 7.1296 µm
#  Inner Radius = 4.8965 µm
#  Thickness = 2.2332 µm
#  Diameter = 14.2593 µm
#  Outer Area = 93.3216 µm²
#  Inner Area = 39.3502 µm²
#  G-Ratio = 0.6868
#  Inner Contours = 1
#
# Axon 121 (mature):
#  Center = (6814.30, 4708.56)
#  Outer Radius = 6.2882 µm
#  Inner Radius = 3.4005 µm
#  Thickness = 2.8877 µm
#  Diameter = 12.5763 µm
#  Outer Area = 84.8596 µm²
#  Inner Area = 25.3210 µm²
#  G-Ratio = 0.5408
#  Inner Contours = 1
#
# Axon 122 (regrowth_cluster):
#  Center = (6697.12, 4703.97)
#  Outer Radius = 11.2516 µm
#  Inner Radius = 3.9252 µm
#  Thickness = 7.3264 µm
#  Diameter = 22.5032 µm
#  Outer Area = 180.4747 µm²
#  Inner Area = 25.3673 µm²
#  G-Ratio = 0.3489
#  Inner Contours = 2
#
# Axon 123 (mature):
#  Center = (6309.98, 4608.92)
#  Outer Radius = 3.3694 µm
#  Inner Radius = 2.4376 µm
#  Thickness = 0.9318 µm
#  Diameter = 6.7388 µm
#  Outer Area = 22.3247 µm²
#  Inner Area = 9.0815 µm²
#  G-Ratio = 0.7235
#  Inner Contours = 1
#
# Axon 124 (mature):
#  Center = (6519.47, 4593.96)
#  Outer Radius = 2.0883 µm
#  Inner Radius = 1.5574 µm
#  Thickness = 0.5309 µm
#  Diameter = 4.1766 µm
#  Outer Area = 9.6642 µm²
#  Inner Area = 5.0956 µm²
#  G-Ratio = 0.7458
#  Inner Contours = 1
#
# Axon 125 (regrowth_cluster):
#  Center = (7073.83, 4584.62)
#  Outer Radius = 4.0557 µm
#  Inner Radius = 2.7979 µm
#  Thickness = 1.2577 µm
#  Diameter = 8.1113 µm
#  Outer Area = 34.1436 µm²
#  Inner Area = 11.1623 µm²
#  G-Ratio = 0.6899
#  Inner Contours = 2
#
# Axon 126 (mature):
#  Center = (6752.21, 4583.85)
#  Outer Radius = 5.3222 µm
#  Inner Radius = 2.0242 µm
#  Thickness = 3.2980 µm
#  Diameter = 10.6444 µm
#  Outer Area = 65.4573 µm²
#  Inner Area = 9.2110 µm²
#  G-Ratio = 0.3803
#  Inner Contours = 1
#
# Axon 127 (mature):
#  Center = (7104.77, 4566.23)
#  Outer Radius = 3.1829 µm
#  Inner Radius = 1.2902 µm
#  Thickness = 1.8927 µm
#  Diameter = 6.3659 µm
#  Outer Area = 13.6963 µm²
#  Inner Area = 2.6634 µm²
#  G-Ratio = 0.4054
#  Inner Contours = 1
#
# Axon 128 (regrowth_cluster):
#  Center = (6608.00, 4577.50)
#  Outer Radius = 7.1232 µm
#  Inner Radius = 3.5595 µm
#  Thickness = 3.5637 µm
#  Diameter = 14.2463 µm
#  Outer Area = 84.3695 µm²
#  Inner Area = 25.1546 µm²
#  G-Ratio = 0.4997
#  Inner Contours = 2
#
# Axon 129 (mature):
#  Center = (6482.56, 4537.59)
#  Outer Radius = 3.2111 µm
#  Inner Radius = 1.8587 µm
#  Thickness = 1.3524 µm
#  Diameter = 6.4222 µm
#  Outer Area = 20.7155 µm²
#  Inner Area = 4.0321 µm²
#  G-Ratio = 0.5788
#  Inner Contours = 1
#
# Axon 130 (regrowth_cluster):
#  Center = (6829.34, 4528.00)
#  Outer Radius = 2.9257 µm
#  Inner Radius = 1.8068 µm
#  Thickness = 1.1189 µm
#  Diameter = 5.8513 µm
#  Outer Area = 18.4220 µm²
#  Inner Area = 5.2899 µm²
#  G-Ratio = 0.6176
#  Inner Contours = 2
#
# Axon 131 (mature):
#  Center = (6398.53, 4492.53)
#  Outer Radius = 3.7456 µm
#  Inner Radius = 2.3987 µm
#  Thickness = 1.3470 µm
#  Diameter = 7.4913 µm
#  Outer Area = 31.1565 µm²
#  Inner Area = 9.9139 µm²
#  G-Ratio = 0.6404
#  Inner Contours = 1
#
# Axon 132 (mature):
#  Center = (7116.45, 4482.16)
#  Outer Radius = 4.0850 µm
#  Inner Radius = 2.1504 µm
#  Thickness = 1.9347 µm
#  Diameter = 8.1700 µm
#  Outer Area = 24.3222 µm²
#  Inner Area = 6.5661 µm²
#  G-Ratio = 0.5264
#  Inner Contours = 1
#
# Axon 133 (mature):
#  Center = (6439.15, 4467.44)
#  Outer Radius = 3.7252 µm
#  Inner Radius = 2.9248 µm
#  Thickness = 0.8004 µm
#  Diameter = 7.4504 µm
#  Outer Area = 24.0263 µm²
#  Inner Area = 8.6746 µm²
#  G-Ratio = 0.7851
#  Inner Contours = 1
#
# Axon 134 (mature):
#  Center = (6923.48, 4421.96)
#  Outer Radius = 3.8074 µm
#  Inner Radius = 2.8037 µm
#  Thickness = 1.0037 µm
#  Diameter = 7.6148 µm
#  Outer Area = 22.9350 µm²
#  Inner Area = 7.1395 µm²
#  G-Ratio = 0.7364
#  Inner Contours = 1
#
# Axon 135 (mature):
#  Center = (6802.74, 4355.54)
#  Outer Radius = 3.1003 µm
#  Inner Radius = 1.9648 µm
#  Thickness = 1.1355 µm
#  Diameter = 6.2006 µm
#  Outer Area = 18.0151 µm²
#  Inner Area = 6.3811 µm²
#  G-Ratio = 0.6338
#  Inner Contours = 1
#
# Axon 136 (mature):
#  Center = (6754.90, 4318.39)
#  Outer Radius = 5.8384 µm
#  Inner Radius = 3.8683 µm
#  Thickness = 1.9701 µm
#  Diameter = 11.6768 µm
#  Outer Area = 71.6350 µm²
#  Inner Area = 20.0959 µm²
#  G-Ratio = 0.6626
#  Inner Contours = 1
#
# Axon 137 (mature):
#  Center = (6344.50, 4324.00)
#  Outer Radius = 7.2109 µm
#  Inner Radius = 2.8152 µm
#  Thickness = 4.3957 µm
#  Diameter = 14.4218 µm
#  Outer Area = 40.2473 µm²
#  Inner Area = 9.1278 µm²
#  G-Ratio = 0.3904
#  Inner Contours = 1
#
# Axon 138 (regrowth_cluster):
#  Center = (7024.50, 4361.00)
#  Outer Radius = 13.2774 µm
#  Inner Radius = 4.3885 µm
#  Thickness = 8.8889 µm
#  Diameter = 26.5549 µm
#  Outer Area = 230.3492 µm²
#  Inner Area = 29.5011 µm²
#  G-Ratio = 0.3305
#  Inner Contours = 4
#
# Axon 139 (mature):
#  Center = (6912.56, 4287.49)
#  Outer Radius = 4.1841 µm
#  Inner Radius = 3.1042 µm
#  Thickness = 1.0799 µm
#  Diameter = 8.3681 µm
#  Outer Area = 33.1078 µm²
#  Inner Area = 15.9158 µm²
#  G-Ratio = 0.7419
#  Inner Contours = 1
#
# Axon 140 (regrowth_cluster):
#  Center = (6842.00, 4239.00)
#  Outer Radius = 5.3888 µm
#  Inner Radius = 4.0487 µm
#  Thickness = 1.3400 µm
#  Diameter = 10.7775 µm
#  Outer Area = 69.8224 µm²
#  Inner Area = 28.9647 µm²
#  G-Ratio = 0.7513
#  Inner Contours = 2
#
# Axon 141 (mature):
#  Center = (6586.50, 4157.00)
#  Outer Radius = 2.9804 µm
#  Inner Radius = 2.4147 µm
#  Thickness = 0.5657 µm
#  Diameter = 5.9608 µm
#  Outer Area = 20.4288 µm²
#  Inner Area = 6.4089 µm²
#  G-Ratio = 0.8102
#  Inner Contours = 1
#
# Axon 142 (mature):
#  Center = (6892.80, 4146.10)
#  Outer Radius = 7.5429 µm
#  Inner Radius = 3.7788 µm
#  Thickness = 3.7641 µm
#  Diameter = 15.0857 µm
#  Outer Area = 87.3104 µm²
#  Inner Area = 30.5184 µm²
#  G-Ratio = 0.5010
#  Inner Contours = 1
#
# Axon 143 (mature):
#  Center = (7802.00, 4998.00)
#  Outer Radius = 6.0394 µm
#  Inner Radius = 4.5209 µm
#  Thickness = 1.5185 µm
#  Diameter = 12.0788 µm
#  Outer Area = 64.6343 µm²
#  Inner Area = 14.3991 µm²
#  G-Ratio = 0.7486
#  Inner Contours = 1
#
# Axon 144 (mature):
#  Center = (7514.50, 4952.50)
#  Outer Radius = 5.2611 µm
#  Inner Radius = 1.8672 µm
#  Thickness = 3.3939 µm
#  Diameter = 10.5222 µm
#  Outer Area = 14.6303 µm²
#  Inner Area = 4.7442 µm²
#  G-Ratio = 0.3549
#  Inner Contours = 1
#
# Axon 145 (regrowth_cluster):
#  Center = (7676.00, 4925.00)
#  Outer Radius = 2.7739 µm
#  Inner Radius = 2.1342 µm
#  Thickness = 0.6397 µm
#  Diameter = 5.5478 µm
#  Outer Area = 13.3356 µm²
#  Inner Area = 3.8379 µm²
#  G-Ratio = 0.7694
#  Inner Contours = 2
#
# Axon 146 (regrowth_cluster):
#  Center = (7467.00, 4886.00)
#  Outer Radius = 7.6861 µm
#  Inner Radius = 4.6663 µm
#  Thickness = 3.0198 µm
#  Diameter = 15.3722 µm
#  Outer Area = 107.4248 µm²
#  Inner Area = 27.1984 µm²
#  G-Ratio = 0.6071
#  Inner Contours = 2
#
# Axon 147 (mature):
#  Center = (7754.50, 4651.00)
#  Outer Radius = 7.3178 µm
#  Inner Radius = 4.5306 µm
#  Thickness = 2.7873 µm
#  Diameter = 14.6357 µm
#  Outer Area = 105.6584 µm²
#  Inner Area = 34.0419 µm²
#  G-Ratio = 0.6191
#  Inner Contours = 1
#
# Axon 148 (regrowth_cluster):
#  Center = (8123.50, 4759.50)
#  Outer Radius = 26.3428 µm
#  Inner Radius = 1.9825 µm
#  Thickness = 24.3603 µm
#  Diameter = 52.6856 µm
#  Outer Area = 445.8461 µm²
#  Inner Area = 3.2738 µm²
#  G-Ratio = 0.0753
#  Inner Contours = 4
#
# Axon 149 (mature):
#  Center = (7737.50, 4570.00)
#  Outer Radius = 2.4565 µm
#  Inner Radius = 1.4345 µm
#  Thickness = 1.0220 µm
#  Diameter = 4.9130 µm
#  Outer Area = 9.5532 µm²
#  Inner Area = 3.0241 µm²
#  G-Ratio = 0.5840
#  Inner Contours = 1
#
# Axon 150 (regrowth_cluster):
#  Center = (7744.50, 4502.00)
#  Outer Radius = 2.9804 µm
#  Inner Radius = 1.3133 µm
#  Thickness = 1.6671 µm
#  Diameter = 5.9608 µm
#  Outer Area = 12.5680 µm²
#  Inner Area = 2.0900 µm²
#  G-Ratio = 0.4406
#  Inner Contours = 2
#
# Axon 151 (regrowth_cluster):
#  Center = (7568.50, 4425.50)
#  Outer Radius = 3.3878 µm
#  Inner Radius = 1.4537 µm
#  Thickness = 1.9341 µm
#  Diameter = 6.7755 µm
#  Outer Area = 14.5194 µm²
#  Inner Area = 3.2738 µm²
#  G-Ratio = 0.4291
#  Inner Contours = 2
#
# Axon 152 (mature):
#  Center = (7587.50, 4374.50)
#  Outer Radius = 2.9874 µm
#  Inner Radius = 2.2939 µm
#  Thickness = 0.6934 µm
#  Diameter = 5.9747 µm
#  Outer Area = 16.8591 µm²
#  Inner Area = 7.4261 µm²
#  G-Ratio = 0.7679
#  Inner Contours = 1
#
# Axon 153 (regrowth_cluster):
#  Center = (7660.00, 4372.50)
#  Outer Radius = 4.3120 µm
#  Inner Radius = 1.2902 µm
#  Thickness = 3.0218 µm
#  Diameter = 8.6240 µm
#  Outer Area = 29.0017 µm²
#  Inner Area = 2.3397 µm²
#  G-Ratio = 0.2992
#  Inner Contours = 2
#
# Axon 154 (mature):
#  Center = (7481.18, 4346.98)
#  Outer Radius = 4.8097 µm
#  Inner Radius = 2.4099 µm
#  Thickness = 2.3998 µm
#  Diameter = 9.6194 µm
#  Outer Area = 52.4639 µm²
#  Inner Area = 11.4213 µm²
#  G-Ratio = 0.5011
#  Inner Contours = 1
#
# Axon 155 (mature):
#  Center = (7514.66, 4284.50)
#  Outer Radius = 5.9664 µm
#  Inner Radius = 2.4795 µm
#  Thickness = 3.4869 µm
#  Diameter = 11.9328 µm
#  Outer Area = 77.7294 µm²
#  Inner Area = 11.3011 µm²
#  G-Ratio = 0.4156
#  Inner Contours = 1
#
# Axon 156 (mature):
#  Center = (7437.58, 4223.47)
#  Outer Radius = 1.9911 µm
#  Inner Radius = 1.2483 µm
#  Thickness = 0.7428 µm
#  Diameter = 3.9823 µm
#  Outer Area = 9.7844 µm²
#  Inner Area = 2.8021 µm²
#  G-Ratio = 0.6269
#  Inner Contours = 1
#
# Axon 157 (mature):
#  Center = (7619.51, 4252.88)
#  Outer Radius = 11.7460 µm
#  Inner Radius = 3.1682 µm
#  Thickness = 8.5778 µm
#  Diameter = 23.4919 µm
#  Outer Area = 104.7521 µm²
#  Inner Area = 19.4855 µm²
#  G-Ratio = 0.2697
#  Inner Contours = 1
#
# Axon 158 (mature):
#  Center = (3747.50, 6123.00)
#  Outer Radius = 13.6694 µm
#  Inner Radius = 1.0156 µm
#  Thickness = 12.6538 µm
#  Diameter = 27.3387 µm
#  Outer Area = 164.7809 µm²
#  Inner Area = 1.9606 µm²
#  G-Ratio = 0.0743
#  Inner Contours = 1
#
# Axon 159 (mature):
#  Center = (5596.50, 5520.50)
#  Outer Radius = 5.7354 µm
#  Inner Radius = 0.9123 µm
#  Thickness = 4.8231 µm
#  Diameter = 11.4709 µm
#  Outer Area = 47.0446 µm²
#  Inner Area = 1.2115 µm²
#  G-Ratio = 0.1591
#  Inner Contours = 1
#
# Axon 160 (mature):
#  Center = (7082.97, 5659.50)
#  Outer Radius = 5.9550 µm
#  Inner Radius = 2.4760 µm
#  Thickness = 3.4790 µm
#  Diameter = 11.9099 µm
#  Outer Area = 31.5634 µm²
#  Inner Area = 8.8411 µm²
#  G-Ratio = 0.4158
#  Inner Contours = 1
#
# Axon 161 (mature):
#  Center = (6855.00, 5443.50)
#  Outer Radius = 3.0540 µm
#  Inner Radius = 0.6271 µm
#  Thickness = 2.4268 µm
#  Diameter = 6.1079 µm
#  Outer Area = 10.7924 µm²
#  Inner Area = 0.9156 µm²
#  G-Ratio = 0.2054
#  Inner Contours = 1
#
# Axon 162 (mature):
#  Center = (7006.00, 5384.50)
#  Outer Radius = 2.1342 µm
#  Inner Radius = 1.6559 µm
#  Thickness = 0.4783 µm
#  Diameter = 4.2683 µm
#  Outer Area = 6.0667 µm²
#  Inner Area = 2.5802 µm²
#  G-Ratio = 0.7759
#  Inner Contours = 1
#
# Axon 163 (regrowth_cluster):
#  Center = (7036.80, 5233.09)
#  Outer Radius = 3.8946 µm
#  Inner Radius = 3.5005 µm
#  Thickness = 0.3941 µm
#  Diameter = 7.7892 µm
#  Outer Area = 26.0516 µm²
#  Inner Area = 9.2850 µm²
#  G-Ratio = 0.8988
#  Inner Contours = 2
#
# Axon 164 (mature):
#  Center = (7069.50, 5161.17)
#  Outer Radius = 5.6680 µm
#  Inner Radius = 3.5989 µm
#  Thickness = 2.0692 µm
#  Diameter = 11.3361 µm
#  Outer Area = 61.7396 µm²
#  Inner Area = 18.2093 µm²
#  G-Ratio = 0.6349
#  Inner Contours = 1
#
# Axon 165 (mature):
#  Center = (7281.50, 5704.50)
#  Outer Radius = 7.8933 µm
#  Inner Radius = 5.4149 µm
#  Thickness = 2.4784 µm
#  Diameter = 15.7866 µm
#  Outer Area = 134.4104 µm²
#  Inner Area = 29.7971 µm²
#  G-Ratio = 0.6860
#  Inner Contours = 1
#
# Axon 166 (mature):
#  Center = (7189.50, 5663.50)
#  Outer Radius = 2.9437 µm
#  Inner Radius = 0.5827 µm
#  Thickness = 2.3610 µm
#  Diameter = 5.8874 µm
#  Outer Area = 10.9589 µm²
#  Inner Area = 0.7491 µm²
#  G-Ratio = 0.1980
#  Inner Contours = 1
#
# Axon 167 (mature):
#  Center = (7190.50, 5623.50)
#  Outer Radius = 3.8479 µm
#  Inner Radius = 2.5087 µm
#  Thickness = 1.3392 µm
#  Diameter = 7.6958 µm
#  Outer Area = 20.7803 µm²
#  Inner Area = 7.9440 µm²
#  G-Ratio = 0.6520
#  Inner Contours = 1
#
# Axon 168 (mature):
#  Center = (7450.00, 5537.19)
#  Outer Radius = 3.5212 µm
#  Inner Radius = 1.2527 µm
#  Thickness = 2.2685 µm
#  Diameter = 7.0424 µm
#  Outer Area = 14.8245 µm²
#  Inner Area = 2.8761 µm²
#  G-Ratio = 0.3558
#  Inner Contours = 1
#
# Axon 169 (regrowth_cluster):
#  Center = (7337.27, 5466.58)
#  Outer Radius = 3.7075 µm
#  Inner Radius = 2.1972 µm
#  Thickness = 1.5103 µm
#  Diameter = 7.4150 µm
#  Outer Area = 26.6990 µm²
#  Inner Area = 6.2609 µm²
#  G-Ratio = 0.5926
#  Inner Contours = 2
#
# Axon 170 (regrowth_cluster):
#  Center = (7418.50, 5403.50)
#  Outer Radius = 7.4819 µm
#  Inner Radius = 3.7974 µm
#  Thickness = 3.6845 µm
#  Diameter = 14.9637 µm
#  Outer Area = 95.3469 µm²
#  Inner Area = 30.0005 µm²
#  G-Ratio = 0.5075
#  Inner Contours = 3
#
# Axon 171 (mature):
#  Center = (7714.00, 5264.50)
#  Outer Radius = 4.2926 µm
#  Inner Radius = 3.4007 µm
#  Thickness = 0.8919 µm
#  Diameter = 8.5853 µm
#  Outer Area = 23.3420 µm²
#  Inner Area = 6.9452 µm²
#  G-Ratio = 0.7922
#  Inner Contours = 1
#
# Axon 172 (mature):
#  Center = (4384.58, 6430.48)
#  Outer Radius = 7.1557 µm
#  Inner Radius = 0.6158 µm
#  Thickness = 6.5399 µm
#  Diameter = 14.3114 µm
#  Outer Area = 53.5829 µm²
#  Inner Area = 0.5919 µm²
#  G-Ratio = 0.0861
#  Inner Contours = 1
#
# Axon 173 (mature):
#  Center = (5994.34, 7145.42)
#  Outer Radius = 3.3360 µm
#  Inner Radius = 2.5389 µm
#  Thickness = 0.7971 µm
#  Diameter = 6.6720 µm
#  Outer Area = 20.9190 µm²
#  Inner Area = 7.0562 µm²
#  G-Ratio = 0.7611
#  Inner Contours = 1
#
# Axon 174 (mature):
#  Center = (5807.50, 7130.50)
#  Outer Radius = 2.1353 µm
#  Inner Radius = 1.5037 µm
#  Thickness = 0.6315 µm
#  Diameter = 4.2705 µm
#  Outer Area = 7.6111 µm²
#  Inner Area = 2.8854 µm²
#  G-Ratio = 0.7042
#  Inner Contours = 1
#
# Axon 175 (mature):
#  Center = (5372.43, 7128.09)
#  Outer Radius = 5.5616 µm
#  Inner Radius = 4.0086 µm
#  Thickness = 1.5530 µm
#  Diameter = 11.1233 µm
#  Outer Area = 63.9777 µm²
#  Inner Area = 21.2889 µm²
#  G-Ratio = 0.7208
#  Inner Contours = 1
#
# Axon 176 (regrowth_cluster):
#  Center = (6022.50, 7109.00)
#  Outer Radius = 4.0005 µm
#  Inner Radius = 2.4939 µm
#  Thickness = 1.5066 µm
#  Diameter = 8.0009 µm
#  Outer Area = 24.1095 µm²
#  Inner Area = 8.0180 µm²
#  G-Ratio = 0.6234
#  Inner Contours = 2
#
# Axon 177 (mature):
#  Center = (5864.00, 6942.00)
#  Outer Radius = 3.3118 µm
#  Inner Radius = 2.6720 µm
#  Thickness = 0.6398 µm
#  Diameter = 6.6237 µm
#  Outer Area = 20.4288 µm²
#  Inner Area = 8.2677 µm²
#  G-Ratio = 0.8068
#  Inner Contours = 1
#
# Axon 178 (mature):
#  Center = (5456.37, 6927.52)
#  Outer Radius = 2.1176 µm
#  Inner Radius = 1.4549 µm
#  Thickness = 0.6627 µm
#  Diameter = 4.2352 µm
#  Outer Area = 9.0630 µm²
#  Inner Area = 3.6900 µm²
#  G-Ratio = 0.6871
#  Inner Contours = 1
#
# Axon 179 (regrowth_cluster):
#  Center = (5933.71, 6732.14)
#  Outer Radius = 2.9027 µm
#  Inner Radius = 0.9306 µm
#  Thickness = 1.9721 µm
#  Diameter = 5.8054 µm
#  Outer Area = 12.9010 µm²
#  Inner Area = 1.9143 µm²
#  G-Ratio = 0.3206
#  Inner Contours = 2
#
# Axon 180 (mature):
#  Center = (6114.24, 6669.34)
#  Outer Radius = 2.7766 µm
#  Inner Radius = 2.1353 µm
#  Thickness = 0.6414 µm
#  Diameter = 5.5532 µm
#  Outer Area = 18.5700 µm²
#  Inner Area = 7.2412 µm²
#  G-Ratio = 0.7690
#  Inner Contours = 1
#
# Axon 181 (regrowth_cluster):
#  Center = (6065.13, 6650.61)
#  Outer Radius = 2.6256 µm
#  Inner Radius = 1.2776 µm
#  Thickness = 1.3479 µm
#  Diameter = 5.2511 µm
#  Outer Area = 13.7795 µm²
#  Inner Area = 2.1363 µm²
#  G-Ratio = 0.4866
#  Inner Contours = 2
#
# Axon 182 (mature):
#  Center = (5797.00, 6602.50)
#  Outer Radius = 3.4412 µm
#  Inner Radius = 2.7517 µm
#  Thickness = 0.6895 µm
#  Diameter = 6.8825 µm
#  Outer Area = 17.3770 µm²
#  Inner Area = 6.6308 µm²
#  G-Ratio = 0.7996
#  Inner Contours = 1
#
# Axon 183 (mature):
#  Center = (6079.66, 6591.58)
#  Outer Radius = 3.0116 µm
#  Inner Radius = 0.9617 µm
#  Thickness = 2.0500 µm
#  Diameter = 6.0233 µm
#  Outer Area = 16.8129 µm²
#  Inner Area = 0.8786 µm²
#  G-Ratio = 0.3193
#  Inner Contours = 1
#
# Axon 184 (mature):
#  Center = (5773.50, 6587.50)
#  Outer Radius = 3.0059 µm
#  Inner Radius = 1.6447 µm
#  Thickness = 1.3612 µm
#  Diameter = 6.0118 µm
#  Outer Area = 17.5804 µm²
#  Inner Area = 3.6437 µm²
#  G-Ratio = 0.5472
#  Inner Contours = 1
#
# Axon 185 (regrowth_cluster):
#  Center = (6077.50, 6514.50)
#  Outer Radius = 5.3759 µm
#  Inner Radius = 2.0011 µm
#  Thickness = 3.3748 µm
#  Diameter = 10.7518 µm
#  Outer Area = 33.7460 µm²
#  Inner Area = 4.8829 µm²
#  G-Ratio = 0.3722
#  Inner Contours = 3
#
# Axon 186 (mature):
#  Center = (6981.99, 7151.54)
#  Outer Radius = 2.1304 µm
#  Inner Radius = 1.5879 µm
#  Thickness = 0.5426 µm
#  Diameter = 4.2608 µm
#  Outer Area = 11.5785 µm²
#  Inner Area = 4.5778 µm²
#  G-Ratio = 0.7453
#  Inner Contours = 1
#
# Axon 187 (mature):
#  Center = (6292.00, 7147.00)
#  Outer Radius = 4.5697 µm
#  Inner Radius = 1.4777 µm
#  Thickness = 3.0920 µm
#  Diameter = 9.1394 µm
#  Outer Area = 14.0385 µm²
#  Inner Area = 3.3293 µm²
#  G-Ratio = 0.3234
#  Inner Contours = 1
#
# Axon 188 (mature):
#  Center = (6638.50, 7135.00)
#  Outer Radius = 3.1640 µm
#  Inner Radius = 2.6598 µm
#  Thickness = 0.5042 µm
#  Diameter = 6.3280 µm
#  Outer Area = 18.7734 µm²
#  Inner Area = 9.2388 µm²
#  G-Ratio = 0.8407
#  Inner Contours = 1
#
# Axon 189 (mature):
#  Center = (6701.73, 7115.51)
#  Outer Radius = 3.9991 µm
#  Inner Radius = 0.6586 µm
#  Thickness = 3.3405 µm
#  Diameter = 7.9982 µm
#  Outer Area = 16.7944 µm²
#  Inner Area = 0.8693 µm²
#  G-Ratio = 0.1647
#  Inner Contours = 1
#
# Axon 190 (mature):
#  Center = (7110.50, 7111.50)
#  Outer Radius = 3.5216 µm
#  Inner Radius = 2.6160 µm
#  Thickness = 0.9056 µm
#  Diameter = 7.0432 µm
#  Outer Area = 20.8450 µm²
#  Inner Area = 11.8189 µm²
#  G-Ratio = 0.7429
#  Inner Contours = 1
#
# Axon 191 (mature):
#  Center = (6417.00, 7100.50)
#  Outer Radius = 2.4414 µm
#  Inner Radius = 1.1215 µm
#  Thickness = 1.3199 µm
#  Diameter = 4.8828 µm
#  Outer Area = 9.3405 µm²
#  Inner Area = 1.7756 µm²
#  G-Ratio = 0.4594
#  Inner Contours = 1
#
# Axon 192 (mature):
#  Center = (7091.50, 7079.00)
#  Outer Radius = 2.4640 µm
#  Inner Radius = 0.8411 µm
#  Thickness = 1.6229 µm
#  Diameter = 4.9280 µm
#  Outer Area = 7.6851 µm²
#  Inner Area = 1.4519 µm²
#  G-Ratio = 0.3414
#  Inner Contours = 1
#
# Axon 193 (mature):
#  Center = (6184.50, 7067.00)
#  Outer Radius = 2.5270 µm
#  Inner Radius = 1.1640 µm
#  Thickness = 1.3630 µm
#  Diameter = 5.0540 µm
#  Outer Area = 10.3948 µm²
#  Inner Area = 2.3305 µm²
#  G-Ratio = 0.4606
#  Inner Contours = 1
#
# Axon 194 (mature):
#  Center = (6753.00, 7038.50)
#  Outer Radius = 1.9860 µm
#  Inner Radius = 1.3080 µm
#  Thickness = 0.6780 µm
#  Diameter = 3.9721 µm
#  Outer Area = 7.2412 µm²
#  Inner Area = 2.7097 µm²
#  G-Ratio = 0.6586
#  Inner Contours = 1
#
# Axon 195 (mature):
#  Center = (6667.50, 7021.50)
#  Outer Radius = 2.2939 µm
#  Inner Radius = 1.5099 µm
#  Thickness = 0.7841 µm
#  Diameter = 4.5879 µm
#  Outer Area = 8.1475 µm²
#  Inner Area = 2.5247 µm²
#  G-Ratio = 0.6582
#  Inner Contours = 1
#
# Axon 196 (regrowth_cluster):
#  Center = (7054.86, 7019.57)
#  Outer Radius = 2.6764 µm
#  Inner Radius = 1.3698 µm
#  Thickness = 1.3066 µm
#  Diameter = 5.3528 µm
#  Outer Area = 8.9058 µm²
#  Inner Area = 2.6542 µm²
#  G-Ratio = 0.5118
#  Inner Contours = 2
#
# Axon 197 (regrowth_cluster):
#  Center = (6956.31, 6995.21)
#  Outer Radius = 2.7538 µm
#  Inner Radius = 2.1298 µm
#  Thickness = 0.6240 µm
#  Diameter = 5.5076 µm
#  Outer Area = 17.2198 µm²
#  Inner Area = 4.2263 µm²
#  G-Ratio = 0.7734
#  Inner Contours = 2
#
# Axon 198 (mature):
#  Center = (6285.00, 6983.00)
#  Outer Radius = 1.8145 µm
#  Inner Radius = 1.2704 µm
#  Thickness = 0.5441 µm
#  Diameter = 3.6290 µm
#  Outer Area = 5.7708 µm²
#  Inner Area = 2.0993 µm²
#  G-Ratio = 0.7001
#  Inner Contours = 1
#
# Axon 199 (regrowth_cluster):
#  Center = (6464.50, 7005.50)
#  Outer Radius = 5.6771 µm
#  Inner Radius = 1.5597 µm
#  Thickness = 4.1174 µm
#  Diameter = 11.3542 µm
#  Outer Area = 31.3137 µm²
#  Inner Area = 4.0044 µm²
#  G-Ratio = 0.2747
#  Inner Contours = 3
#
# Axon 200 (regrowth_cluster):
#  Center = (6235.50, 6983.00)
#  Outer Radius = 4.6643 µm
#  Inner Radius = 3.2817 µm
#  Thickness = 1.3827 µm
#  Diameter = 9.3287 µm
#  Outer Area = 44.0575 µm²
#  Inner Area = 15.5921 µm²
#  G-Ratio = 0.7036
#  Inner Contours = 2
#
# Axon 201 (regrowth_cluster):
#  Center = (7062.50, 6936.00)
#  Outer Radius = 2.7780 µm
#  Inner Radius = 1.3399 µm
#  Thickness = 1.4381 µm
#  Diameter = 5.5561 µm
#  Outer Area = 14.8245 µm²
#  Inner Area = 3.1073 µm²
#  G-Ratio = 0.4823
#  Inner Contours = 2
#
# Axon 202 (mature):
#  Center = (6401.00, 6893.00)
# ...
# 564     132.809129           NaN  0.495628
# 565     132.477876           NaN  0.791857
# 566     131.271203           NaN  0.792282
# 567     133.895954           NaN  0.678572
# 568     134.757653           NaN  0.708774
# 569     132.107345           NaN  0.567904
# 570     129.398048           NaN  0.756396
# 571     133.796610           NaN  0.259820
# 572     130.463394           NaN  0.642475
# 573     130.940904           NaN  0.729550
# 574     132.847826           NaN  0.297005
# 575     132.845070           NaN  0.207445
# 576     129.176673           NaN  0.311834
# 577     137.081301           NaN  0.337239
# 578     132.225610           NaN  0.616114
# 579     132.730198           NaN  0.827095
# 580     132.722944           NaN  0.810871
# 581     135.952880           NaN  0.389747
# 582     132.340206           NaN  0.801174
# 583     135.000000           NaN  0.691546
# 584     128.873171           NaN  0.155034
# 585     132.006309           NaN  0.161058
# 586     129.947826           NaN  0.222455
# 587     134.715640           NaN  0.141238
# 588     124.137500           NaN  0.267376
# 589     129.553930           NaN  0.652491
# 590     133.713592           NaN  0.744748
# 591     130.623251           NaN  0.391041
# 592     131.985075           NaN  0.711224
# 593     130.535509           NaN  0.826657
# 594     131.225806           NaN  0.437557
# 595     130.485425           NaN  0.535779
# 596     136.891386           NaN  0.787658
# 597     129.919747           NaN  0.666213
# 598     132.144981           NaN  0.465005
# 599     133.072000           NaN  0.759259
# 600     131.407035           NaN  0.772037
# 601     133.013986           NaN  0.595911
# 602     131.410494           NaN  0.352931
# 603     130.352995           NaN  0.628588
# 604     129.837778           NaN  0.734923
# 605     135.039216           NaN  0.196119
# 606     130.777273           NaN  0.390386
# 607     129.511879           NaN  0.481242
# 608     133.303922           NaN  0.355831
# 609     129.333333           NaN  0.187881
# 610     134.165746           NaN  0.775441
# 611     131.401042           NaN  0.474791
# 612     133.480315           NaN  0.386121
# 613     130.038511           NaN  0.385671
# 614     130.295220           NaN  0.389184
# 615     131.865116           NaN  0.410692
# 616     130.148115           NaN  0.579080
# 617     132.982906           NaN  0.773902
# 618     130.068323           NaN  0.416766
# 619     129.370443           NaN  0.711342
# 620     133.470588           NaN  0.568138
# 621     131.574514           NaN  0.645474
# 622     129.778351           NaN  0.555802
# 623     133.142655           NaN  0.720313
# 624     131.493333           NaN  0.630238
# 625     134.326460           NaN  0.503026
# 626     130.617521           NaN  0.455062
# 627     129.928458           NaN  0.598884
# 628     131.261364           NaN  0.590023
# 629     129.783486           NaN  0.591048
# 630     132.967742           NaN  0.341022
# 631     132.593220           NaN  0.757876
# 632     128.925926           NaN  0.085460
# 633     131.257143           NaN  0.819233
# 634     131.359223           NaN  0.110779
# 635     138.314159           NaN  0.184511
# 636     138.623377           NaN  0.051581
# 637     130.255521           NaN  0.785313
# 638     130.696935           NaN  0.589364
# 639     132.412556           NaN  0.445023
# 640     131.384211           NaN  0.447889
# 641     130.421661           NaN  0.543909
# 642     141.870130           NaN  0.352307
# 643     131.775510           NaN  0.346550
# 644     131.788274           NaN  0.554291
# 645     136.098361           NaN  0.166222
# 646     134.780645           NaN  0.444282
# 647     129.734227           NaN  0.655308
# 648     129.655593           NaN  0.487451
# 649     131.541471           NaN  0.811090
# 650     129.858913           NaN  0.535813
# 651     129.870304           NaN  0.574668
# 652     133.549451           NaN  0.315004
# 653     129.753135           NaN  0.651214
# 654     132.972182           NaN  0.162520
# 655     140.964497           NaN  0.120121
# 656     132.484740           NaN  0.611316
# 657     134.436923           NaN  0.674399
# 658     130.126056           NaN  0.689286
# 659     129.250706           NaN  0.623395
# 660     131.199005           NaN  0.512617
# 661     133.568862           NaN  0.412918
# 662     130.616027           NaN  0.726263
# 663     130.881735           NaN  0.600001
# 664     130.250383           NaN  0.587357
# 665     130.959250           NaN  0.721126
# 666     132.835498           NaN  0.456064
# 667     130.781931           NaN  0.553708
# 668     130.159542           NaN  0.712285
# 669     131.837209           NaN  0.302479
# 670     136.618182           NaN  0.301381
# 671     129.594389           NaN  0.692136
# 672     130.351911           NaN  0.509261
# 673     131.247649           NaN  0.409794
# 674     129.483911           NaN  0.593398
# 675     129.780374           NaN  0.625134
# 676     129.624277           NaN  0.668573
# 677     132.172275           NaN  0.755547
# 678     133.219858           NaN  0.640691
# 679     133.694444           NaN  0.399478
# 680     131.725888           NaN  0.413250
# 681     129.508067           NaN  0.551003
# 682     129.403649           NaN  0.381972
# 683     132.304878           NaN  0.348602
# 684     129.504333           NaN  0.532342
# 685     133.620000           NaN  0.310770
# 686     131.357341           NaN  0.353241
# 687     132.049217           NaN  0.782759
# 688     130.378190           NaN  0.826589
# 689     131.563830           NaN  0.316231
# 690     130.087079           NaN  0.707108
# 691     133.857143           NaN  0.404480
# 692     132.386570           NaN  0.626388
# 693     130.846154           NaN  0.732364
# 694     129.906977           NaN  0.393091
# 695     132.890733           NaN  0.578395
# 696     130.563934           NaN  0.689898
# 697     135.365385           NaN  0.227935
# 698     132.133962           NaN  0.752069
# 699     134.862500           NaN  0.762339
# 700     130.728634           NaN  0.557613
# 701     133.961538           NaN  0.435547
# 702     131.027864           NaN  0.787575
# 703     129.882711           NaN  0.780044
# 704     135.420635           NaN  0.347883
# 705     133.367347           NaN  0.594996
# 706     131.975962           NaN  0.515322
# 707     129.538663           NaN  0.586400
# 708     131.935211           NaN  0.542635
# 709     129.969717           NaN  0.749821
# 710     131.380851           NaN  0.659885
# 711     129.318033           NaN  0.452026
# 712     131.977143           NaN  0.688459
# 713     134.346939           NaN  0.565315
# 714     132.915200           NaN  0.799382
# 715     132.801724           NaN  0.597972
# 716     132.583039           NaN  0.487381
# 717     131.316883           NaN  0.729927
# 718     135.779661           NaN  0.311972
# 719     131.464497           NaN  0.506930
# 720     131.252669           NaN  0.354865
# 721     131.938679           NaN  0.510362
# 722     131.876777           NaN  0.755382
# 723     132.692308           NaN  0.511027
# 724     132.137615           NaN  0.368547
# 725     134.089888           NaN  0.300532
# 726     132.356322           NaN  0.571431
# 727     130.797872           NaN  0.392946
# 728     133.383721           NaN  0.544742
# 729     130.357524           NaN  0.398655
# 730     132.070064           NaN  0.587513
# 731     134.380165           NaN  0.425930
# 732     135.172727           NaN  0.431011
# 733     134.720000           NaN  0.555685
# 734     132.216080           NaN  0.335758
# 735     134.867925           NaN  0.155530
# 736     133.028986           NaN  0.616024
# 737     133.769231           NaN  0.267152
# 738     131.207705           NaN  0.723722
# 739     134.233129           NaN  0.705645
# 740     129.209371           NaN  0.696794
# 741     133.426901           NaN  0.525434
# 742     135.588710           NaN  0.406547
# 743     134.339623           NaN  0.489532
# 744     132.103734           NaN  0.532513
# 745     130.987179           NaN  0.430599
# 746     130.305603           NaN  0.771840
# 747     129.912791           NaN  0.260194
# 748     130.914393           NaN  0.500531
# 749     130.223356           NaN  0.626558
# 750     134.089552           NaN  0.219242
# 751     133.218310           NaN  0.552764
# 752     131.188552           NaN  0.755801
# 753     145.409091           NaN  0.046010
# 754     130.276190           NaN  0.770657
# 755     130.114743           NaN  0.539614
# 756     134.250000           NaN  0.256887
# 757     131.848649           NaN  0.515311
# 758     130.100559           NaN  0.421264
# 759     133.449664           NaN  0.687519
# 760     129.661703           NaN  0.484378
# 761     129.909817           NaN  0.589711
# 762     134.617143           NaN  0.555587
# 763     129.658938           NaN  0.618000
# 764     133.099164           NaN  0.571305
# 765     131.906952           NaN  0.758964
# 766     131.920161           NaN  0.583832
# 767     129.802142           NaN  0.761191
# 768     130.880978           NaN  0.526779
# 769     131.904232           NaN  0.443258
# 770     132.029086           NaN  0.291691
# 771     130.227523           NaN  0.633275
# 772     132.045837           NaN  0.699949
# 773     134.245283           NaN  0.201601
# 774     133.261905           NaN  0.196120
# 775     135.600000           NaN  0.358511
# 776     136.184874           NaN  0.244132
# 777     131.745665           NaN  0.462860
# 778     129.205882           NaN  0.680369
# 779     132.916667           NaN  0.679462
# 780     143.482759           NaN  0.121501
# 781     138.540816           NaN  0.211484
# 782     134.294118           NaN  0.257674
# 783     134.793522           NaN  0.493532
# 784     133.574675           NaN  0.689325
# 785     134.181583           NaN  0.443034
# 786     141.164948           NaN  0.556901
# 787     133.808712           NaN  0.357915
# 788     137.826772           NaN  0.328641
# 789     145.282828           NaN  0.372146
# 790     131.687050           NaN  0.548380
# 791     137.178571           NaN  0.344022
# 792     129.941909           NaN  0.721871
# 793     129.632630           NaN  0.652733
# 794     133.347140           NaN  0.708521
# 795     142.000000           NaN  0.247590
# 796     139.610000           NaN  0.405471
# 797     129.337242           NaN  0.707009
# 798     130.625922           NaN  0.861565
# 799     131.908228           NaN  0.660244
# 800     135.298246           NaN  0.404478
# 801     134.492754           NaN  0.232053
# 802     131.544365           NaN  0.598722
# 803     132.098394           NaN  0.744758
# 804     131.205451           NaN  0.499837
# 805     130.592920           NaN  0.465603
# 806     131.251527           NaN  0.533252
# 807     129.789702           NaN  0.457220
# 808     133.178082           NaN  0.585665
# 809     129.185000           NaN  0.604785
# 810     130.788009           NaN  0.237164
# 811     129.362453           NaN  0.596487
# 812     133.064286           NaN  0.372277
# 813     130.462766           NaN  0.477108
# 814     132.636986           NaN  0.782092
# 815     133.548223           NaN  0.815641
# 816     132.491803           NaN  0.517988
# 817     135.547297           NaN  0.340408
# 818     133.783784           NaN  0.226744
# 819     132.673640           NaN  0.261451
# 820     131.419251           NaN  0.700347
# 821     136.018553           NaN  0.647217
# 822     132.556962           NaN  0.818406
# 823     131.687919           NaN  0.658794
# 824     132.215686           NaN  0.132558
# 825     131.516949           NaN  0.375092
# 826     134.653061           NaN  0.231401
# 827     130.438462           NaN  0.210877
# 828     135.895470           NaN  0.316229
# 829     130.755882           NaN  0.585545
# 830     129.515186           NaN  0.628295
# 831     129.420189           NaN  0.662892
# 832     134.338608           NaN  0.740307
# 833     131.475410           NaN  0.758278
# 834     131.123810           NaN  0.618043
# 835     134.101124           NaN  0.514653
# 836     132.008677           NaN  0.653679
# 837     133.246377           NaN  0.521560
# 838     132.384615           NaN  0.609382
# 839     130.282633           NaN  0.541453
# 840     132.009950           NaN  0.476841
# 841     139.730769           NaN  0.507378
# 842     129.814470           NaN  0.730688
# 843     129.314248           NaN  0.691358
# 844     132.005184           NaN  0.622559
# 845     133.828571           NaN  0.294010
# 846     130.405585           NaN  0.798969
# 847     132.258216           NaN  0.641894
# 848     130.034230           NaN  0.704281
# 849     130.948663           NaN  0.741424
# 850     132.782427           NaN  0.574149
# 851     133.801653           NaN  0.472440
# 852     131.989305           NaN  0.419254
# 853     129.392771           NaN  0.707458
# 854     129.779867           NaN  0.551687
# 855     131.650235           NaN  0.774705
# 856     134.161094           NaN  0.358094
# 857     130.409490           NaN  0.459196
# 858     133.754237           NaN  0.488186
# 859     129.064984           NaN  0.684537
# 860     129.792178           NaN  0.618279
# 861     130.055066           NaN  0.678945
# 862     135.466667           NaN  0.236793
# 863     132.865140           NaN  0.720168
# 864     132.989831           NaN  0.756950
# 865     129.716268           NaN  0.586364
# 866     130.155290           NaN  0.431211
# 867     129.689995           NaN  0.553793
# 868     130.829604           NaN  0.786056
# 869     129.422928           NaN  0.677927
# 870     133.386207           NaN  0.638767
# 871     131.122807           NaN  0.767163
# 872     133.818510           NaN  0.548685
# 873     139.067164           NaN  0.660114
# 874     136.545276           NaN  0.310481
# 875     133.070888           NaN  0.599805
# 876     137.472289           NaN  0.766723
# 877     131.804348           NaN  0.658060
# 878     134.315888           NaN  0.377329
# 879     136.774823           NaN  0.645372
# 880     130.645614           NaN  0.679704
# 881     140.297030           NaN  0.487500
# 882     133.929057           NaN  0.389462
# 883     130.963910           NaN  0.712558
# 884     146.710843           NaN  0.286545
# 885     133.281188           NaN  0.310790
# 886     138.223684           NaN  0.303423
# 887     130.400754           NaN  0.717539
# 888     130.607942           NaN  0.531655
# 889     130.521269           NaN  0.560821
# 890     132.917453           NaN  0.832130
# 891     129.361288           NaN  0.590458
# 892     134.679783           NaN  0.713637
# 893     132.970492           NaN  0.552815
# 894     131.976471           NaN  0.277352
# 895     142.730769           NaN  0.245231
# 896     131.935185           NaN  0.835933
# 897     128.043307           NaN  0.190410
# 898     131.220930           NaN  0.299562
# 899     125.659836           NaN  0.229447
# 900     145.127273           NaN  0.026761
# 901     144.487805           NaN  0.440429
# 902     140.729167           NaN  0.272880
# 903     130.565471           NaN  0.662253
# 904     139.089613           NaN  0.365573
# 905     140.800000           NaN  0.474507
# 906     131.158103           NaN  0.415435
# 907     136.542857           NaN  0.303429
# 908     130.311475           NaN  0.113375
# 909     133.015517           NaN  0.347535
# 910     135.733333           NaN  0.242539
# 911     142.384615           NaN  0.144654
#
# ✅ Plots saved in 'C:\Users\DELL\Downloads\40x_bf_02_qwerty5_4_statistics_regrowth_all'
#
# 📊 Summary:
# Number of mature axons: 668
# Number of regrowth clusters: 244
# Number of total regrowth axons: 593
#
#
# ✅ All CSV + plots + summary saved in 'C:\Users\DELL\Downloads\40x_bf_02_qwerty5_4_statistics_regrowth_all'

# %%
import cv2
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# --------------------------
# Input and output paths
# --------------------------
image_path = r"C:\Users\sanje\Downloads\low density clip 2.png"
output_folder = r"C:\Users\sanje\Downloads\lowdensity_qwerty5_4_statistics_regrowthandmature_g_ar"
os.makedirs(output_folder, exist_ok=True)

# Scale factor (µm/px)
scale_factor = 0.136

# --------------------------
# Tunables
# --------------------------
TISSUE_OVERLAP_MIN = 0.50
MAX_MEAN_INTENSITY = 245
MIN_CIRCULARITY = 0.10
MIN_CONTOUR_AREA = 20
MAX_CONTOUR_AREA = 2000000
MIN_SOLIDITY = 0.3  # adjust based on dataset

# --------------------------
# Helpers
# --------------------------
def darken_and_sharpen(image):
    darkened = cv2.convertScaleAbs(image, alpha=1.5, beta=-20)
    sharpen_kernel = np.array([[0, -1, 0],
                               [-1, 5, -1],
                               [0, -1, 0]])
    return cv2.filter2D(darkened, -1, sharpen_kernel)

def build_tissue_mask(full_image):
    hsv = cv2.cvtColor(full_image, cv2.COLOR_BGR2HSV)
    H, S, V = cv2.split(hsv)
    sat_mask = cv2.inRange(S, 15, 255)
    not_too_bright = cv2.inRange(V, 0, 250)
    mask = cv2.bitwise_and(sat_mask, not_too_bright)
    k = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (7, 7))
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, k, iterations=1)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, k, iterations=2)
    return mask

def contour_overlap_ratio(contour, mask):
    c_mask = np.zeros(mask.shape, dtype=np.uint8)
    cv2.drawContours(c_mask, [contour], -1, 255, -1)
    inter = cv2.bitwise_and(c_mask, mask)
    area_c = cv2.countNonZero(c_mask)
    area_i = cv2.countNonZero(inter)
    return area_i / float(area_c) if area_c > 0 else 0.0

def circularity(contour):
    a = cv2.contourArea(contour)
    p = cv2.arcLength(contour, True)
    return 4 * np.pi * a / (p * p + 1e-6) if p > 0 else 0

# --------------------------
# Main patch processing
# --------------------------
def process_patch(patch, mask_patch, x_offset, y_offset, axon_data, object_counter, output_image):
    patch = darken_and_sharpen(patch)
    gray = cv2.cvtColor(patch, cv2.COLOR_BGR2GRAY)

    # Contrast enhancement
    clahe = cv2.createCLAHE(clipLimit=2.5, tileGridSize=(8, 8))
    enhanced = clahe.apply(gray)

    # Thresholding
    blurred = cv2.GaussianBlur(enhanced, (3, 3), 0)
    _, otsu = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    adaptive = cv2.adaptiveThreshold(
        blurred, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
        cv2.THRESH_BINARY_INV, 35, 2
    )
    thresh = cv2.bitwise_or(otsu, adaptive)

    # Clean
    kernel = np.ones((3, 3), np.uint8)
    cleaned = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=1)

    contours, hierarchy = cv2.findContours(cleaned, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    if hierarchy is None:
        return object_counter
    hierarchy = hierarchy[0]

    for i, contour in enumerate(contours):
        if hierarchy[i][3] != -1:  # only outer contours
            continue

        area = cv2.contourArea(contour)
        if area < MIN_CONTOUR_AREA or area > MAX_CONTOUR_AREA:
            continue

        overlap = contour_overlap_ratio(contour, mask_patch)
        if overlap < TISSUE_OVERLAP_MIN:
            continue

        hull = cv2.convexHull(contour)
        solidity = area / (cv2.contourArea(hull) + 1e-6)
        circ = circularity(contour)
        if solidity < MIN_SOLIDITY or circ < MIN_CIRCULARITY:
            continue

        # Inner children
        inner_children = []
        for j, child in enumerate(contours):
            if hierarchy[j][3] == i and cv2.contourArea(child) > 30:
                inner_children.append(child)
        if len(inner_children) == 0:
            continue

        axon_type = "mature" if len(inner_children) == 1 else "regrowth_cluster"
        largest_inner = max(inner_children, key=cv2.contourArea)

        # Outer
        (x_outer, y_outer), outer_radius = cv2.minEnclosingCircle(contour)
        contour_shifted = contour + np.array([x_offset, y_offset])
        x_outer += x_offset
        y_outer += y_offset
        outer_area_px = cv2.contourArea(contour)
        outer_area_um2 = outer_area_px * (scale_factor**2)

        # Inner
        (x_inner, y_inner), inner_radius = cv2.minEnclosingCircle(largest_inner)
        inner_shifted = largest_inner + np.array([x_offset, y_offset])
        cv2.drawContours(output_image, [contour_shifted], -1, (255, 0, 0), 1)
        cv2.drawContours(output_image, [inner_shifted], -1, (0, 255, 0), 1)
        inner_area_px = cv2.contourArea(largest_inner)
        inner_area_um2 = inner_area_px * (scale_factor**2)

        # Metrics
        thickness = (outer_radius - inner_radius) * scale_factor
        g_ratio = inner_radius / (outer_radius + 1e-6)

        axon_data.append({
            "axon_id": object_counter,
            "axon_type": axon_type,
            "outer_radius": outer_radius * scale_factor,
            "inner_radius": inner_radius * scale_factor,
            "thickness": thickness,
            "diameter": (2 * outer_radius) * scale_factor,
            "outer_area": outer_area_um2,
            "inner_area": inner_area_um2,
            "g_ratio": g_ratio
        })

        # Numbering
        cv2.putText(output_image, str(object_counter),
                    (int(x_outer), int(y_outer)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)

        object_counter += 1

    return object_counter

# --------------------------
# Whole image tiling
# --------------------------
def process_image(image_path, patch_size=1024):
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    if image is None:
        raise ValueError("Could not read image")

    tissue_mask_full = build_tissue_mask(image)
    h, w = image.shape[:2]
    output_image = image.copy()
    axon_data = []
    object_counter = 1

    for y in range(0, h, patch_size):
        for x in range(0, w, patch_size):
            patch = image[y:y+patch_size, x:x+patch_size]
            mask_patch = tissue_mask_full[y:y+patch_size, x:x+patch_size]
            object_counter = process_patch(
                patch, mask_patch, x, y, axon_data, object_counter, output_image
            )

    filename = os.path.basename(image_path)
    output_path = os.path.join(output_folder, f"numbered_{filename}")
    cv2.imwrite(output_path, output_image)

    print(f"\nProcessed: {filename}")
    print(f"Axons detected: {len(axon_data)}\n")
    return axon_data, output_image

# --------------------------
# Save data to CSV
# --------------------------
def save_to_csv(axon_data, output_folder, filename="axon_measurements.csv"):
    df = pd.DataFrame(axon_data)
    csv_path = os.path.join(output_folder, filename)
    df.to_csv(csv_path, index=False)
    print(f"✅ Axon data saved to: {csv_path}")
    return df

# --------------------------
# G-ratio Analysis
# --------------------------
def analyze_g_ratio(df, output_folder, threshold_range=(0.6, 0.8)):
    # Total axons
    total_axons = len(df)
    print(f"\n📊 Total axons detected: {total_axons}")

    # G-ratio values
    g_ratios = df["g_ratio"].dropna().values
    mean_g = np.mean(g_ratios) if len(g_ratios) > 0 else None
    median_g = np.median(g_ratios) if len(g_ratios) > 0 else None
    print(f"✅ Computed g-ratios for {len(g_ratios)} axons")

    # Explain calculation
    print("\nℹ️ G-ratio is calculated as:")
    print("   g_ratio = inner_radius / outer_radius")
    print("   (both radii in micrometers after scaling)\n")

    # --- Plot 1: With expected range + mean line ---
    plt.figure(figsize=(6, 4))
    plt.hist(g_ratios, bins=30, color="lightblue", edgecolor="black", alpha=0.7)

    plt.axvspan(threshold_range[0], threshold_range[1], color="red", alpha=0.2,
                label=f"Expected range {threshold_range[0]}–{threshold_range[1]}")

    if mean_g is not None:
        plt.axvline(mean_g, color="blue", linestyle="--", linewidth=2,
                    label=f"Mean g-ratio = {mean_g:.3f}")

    plt.title("G-ratio Distribution (with expected range)")
    plt.xlabel("g-ratio")
    plt.ylabel("Frequency")
    plt.legend()
    plt.grid(True, linestyle="--", alpha=0.6)

    out_path1 = os.path.join(output_folder, "g_ratio_distribution_with_range.png")
    plt.savefig(out_path1, dpi=150, bbox_inches="tight")
    plt.close()

    # --- Plot 2: Only mean line ---
    plt.figure(figsize=(6, 4))
    plt.hist(g_ratios, bins=30, color="lightblue", edgecolor="black", alpha=0.7)

    if mean_g is not None:
        plt.axvline(mean_g, color="blue", linestyle="--", linewidth=2,
                    label=f"Mean g-ratio = {mean_g:.3f}")

    plt.title("G-ratio Distribution (mean only)")
    plt.xlabel("g-ratio")
    plt.ylabel("Frequency")
    plt.legend()
    plt.grid(True, linestyle="--", alpha=0.6)

    out_path2 = os.path.join(output_folder, "g_ratio_distribution_mean_only.png")
    plt.savefig(out_path2, dpi=150, bbox_inches="tight")
    plt.close()

    # --- Plot 3: Mean + Median lines ---
    plt.figure(figsize=(6, 4))
    plt.hist(g_ratios, bins=30, color="lightblue", edgecolor="black", alpha=0.7)

    if mean_g is not None:
        plt.axvline(mean_g, color="blue", linestyle="--", linewidth=2,
                    label=f"Mean g-ratio = {mean_g:.3f}")
    if median_g is not None:
        plt.axvline(median_g, color="green", linestyle="-.", linewidth=2,
                    label=f"Median g-ratio = {median_g:.3f}")

    plt.title("G-ratio Distribution (mean vs median)")
    plt.xlabel("g-ratio")
    plt.ylabel("Frequency")
    plt.legend()
    plt.grid(True, linestyle="--", alpha=0.6)

    out_path3 = os.path.join(output_folder, "g_ratio_distribution_mean_median.png")
    plt.savefig(out_path3, dpi=150, bbox_inches="tight")
    plt.close()

    print(f"📈 Saved plots:\n - {out_path1}\n - {out_path2}\n - {out_path3}")

    return total_axons, g_ratios, mean_g, median_g



# --------------------------
# Complete plots for mature vs regenerated axons
# --------------------------
def analyze_area_and_g_ratio_complete(df, output_folder):
    df['area_ratio'] = df['inner_area'] / (df['outer_area'] + 1e-6)

    axon_types = ['mature', 'regrowth_cluster']
    metrics = ['area_ratio', 'g_ratio']

    colors = {
        'mature': {'area_ratio': 'skyblue', 'g_ratio': 'lightgreen'},
        'regrowth_cluster': {'area_ratio': 'salmon', 'g_ratio': 'lightcoral'}
    }

    for ax_type in axon_types:
        subset = df[df['axon_type'] == ax_type]
        for metric in metrics:
            data = subset[metric].dropna()
            if len(data) == 0:
                continue

            # Histogram
            plt.figure(figsize=(6,4))
            plt.hist(data, bins=30, color=colors[ax_type][metric], edgecolor='black', alpha=0.7)
            plt.title(f"{metric.replace('_',' ').title()} Histogram ({ax_type.title()} Axons)")
            plt.xlabel(metric.replace('_',' ').title())
            plt.ylabel("Frequency")
            plt.grid(True, linestyle='--', alpha=0.6)
            plt.savefig(os.path.join(output_folder, f"hist_{metric}_{ax_type}.png"), dpi=150, bbox_inches='tight')
            plt.close()

            # Boxplot
            plt.figure(figsize=(4,6))
            plt.boxplot(data, vert=True, patch_artist=True,
                        boxprops=dict(facecolor=colors[ax_type][metric], color='black'))
            plt.title(f"{metric.replace('_',' ').title()} Boxplot ({ax_type.title()} Axons)")
            plt.ylabel(metric.replace('_',' ').title())
            plt.grid(True, linestyle='--', alpha=0.6)
            plt.savefig(os.path.join(output_folder, f"box_{metric}_{ax_type}.png"), dpi=150, bbox_inches='tight')
            plt.close()

    print("📊 Complete plots saved for area_ratio and g_ratio by axon type (mature & regrowth).")

# --------------------------
# Run complete analysis plots
# --------------------------


# --------------------------
# Summary
# --------------------------
def save_summary(df, output_folder, threshold_range=(0.6, 0.8)):
    summary_path = os.path.join(output_folder, "summary.txt")

    total_axons = len(df)
    g_ratios = df["g_ratio"].dropna().values

    mean_g = np.mean(g_ratios) if len(g_ratios) > 0 else None
    median_g = np.median(g_ratios) if len(g_ratios) > 0 else None

    # Percentage within threshold range
    if len(g_ratios) > 0:
        within_range = np.sum((g_ratios >= threshold_range[0]) & (g_ratios <= threshold_range[1]))
        percent_in_range = (within_range / len(g_ratios)) * 100
    else:
        percent_in_range = 0.0

    with open(summary_path, "w") as f:
        f.write("Axon Analysis Summary\n")
        f.write("====================\n\n")
        f.write(f"Total axons detected: {total_axons}\n")
        if mean_g is not None:
            f.write(f"Mean g-ratio: {mean_g:.4f}\n")
        if median_g is not None:
            f.write(f"Median g-ratio: {median_g:.4f}\n")
        f.write(f"Axons within expected range {threshold_range[0]}–{threshold_range[1]}: {percent_in_range:.2f}%\n")

    print(f"📝 Summary saved at: {summary_path}")


# --------------------------
# Run Pipeline
# --------------------------
axon_data, output_image = process_image(image_path, patch_size=1024)
df = save_to_csv(axon_data, output_folder)
total_axons, g_ratios, mean_g, median_g = analyze_g_ratio(df, output_folder)
analyze_area_and_g_ratio_complete(df, output_folder)
save_summary(df, output_folder)

print(f"\n✅ Done: CSV, g-ratio analysis, and summary saved in '{output_folder}'")
#with g-ratio, and diff btw regrowth and mature for area-ratio and g-ratio
# Out:
# Processed: low density clip 2.png
# Axons detected: 125
#
# ✅ Axon data saved to: C:\Users\sanje\Downloads\lowdensity_qwerty5_4_statistics_regrowthandmature_g_ar\axon_measurements.csv
#
# 📊 Total axons detected: 125
# ✅ Computed g-ratios for 125 axons
#
# ℹ️ G-ratio is calculated as:
#    g_ratio = inner_radius / outer_radius
#    (both radii in micrometers after scaling)
#
# 📈 Saved plots:
#  - C:\Users\sanje\Downloads\lowdensity_qwerty5_4_statistics_regrowthandmature_g_ar\g_ratio_distribution_with_range.png
#  - C:\Users\sanje\Downloads\lowdensity_qwerty5_4_statistics_regrowthandmature_g_ar\g_ratio_distribution_mean_only.png
#  - C:\Users\sanje\Downloads\lowdensity_qwerty5_4_statistics_regrowthandmature_g_ar\g_ratio_distribution_mean_median.png
# 📊 Complete plots saved for area_ratio and g_ratio by axon type (mature & regrowth).
# 📝 Summary saved at: C:\Users\sanje\Downloads\lowdensity_qwerty5_4_statistics_regrowthandmature_g_ar\summary.txt
#
# ✅ Done: CSV, g-ratio analysis, and summary saved in 'C:\Users\sanje\Downloads\lowdensity_qwerty5_4_statistics_regrowthandmature_g_ar'

# %%
"C:\Users\sanje\Downloads\high density clip.png"
"C:\Users\sanje\Downloads\low density clip 2.png"

# %%
import cv2
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# --------------------------
# Input and output paths
# --------------------------
image_path = r"C:\Users\sanje\Downloads\low density clip 2.png"
output_folder = r"C:\Users\sanje\Downloads\lowdensity_qwerty5_4_statistics_regrowthandmature_gvsdia2"
os.makedirs(output_folder, exist_ok=True)

# Scale factor (µm/px)
scale_factor = 0.136

# --------------------------
# Tunables
# --------------------------
TISSUE_OVERLAP_MIN = 0.50
MAX_MEAN_INTENSITY = 245
MIN_CIRCULARITY = 0.10
MIN_CONTOUR_AREA = 20
MAX_CONTOUR_AREA = 2000000
MIN_SOLIDITY = 0.3  # adjust based on dataset

# --------------------------
# Helpers
# --------------------------
def darken_and_sharpen(image):
    darkened = cv2.convertScaleAbs(image, alpha=1.5, beta=-20)
    sharpen_kernel = np.array([[0, -1, 0],
                               [-1, 5, -1],
                               [0, -1, 0]])
    return cv2.filter2D(darkened, -1, sharpen_kernel)

def build_tissue_mask(full_image):
    hsv = cv2.cvtColor(full_image, cv2.COLOR_BGR2HSV)
    H, S, V = cv2.split(hsv)
    sat_mask = cv2.inRange(S, 15, 255)
    not_too_bright = cv2.inRange(V, 0, 250)
    mask = cv2.bitwise_and(sat_mask, not_too_bright)
    k = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (7, 7))
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, k, iterations=1)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, k, iterations=2)
    return mask

def contour_overlap_ratio(contour, mask):
    c_mask = np.zeros(mask.shape, dtype=np.uint8)
    cv2.drawContours(c_mask, [contour], -1, 255, -1)
    inter = cv2.bitwise_and(c_mask, mask)
    area_c = cv2.countNonZero(c_mask)
    area_i = cv2.countNonZero(inter)
    return area_i / float(area_c) if area_c > 0 else 0.0

def circularity(contour):
    a = cv2.contourArea(contour)
    p = cv2.arcLength(contour, True)
    return 4 * np.pi * a / (p * p + 1e-6) if p > 0 else 0

# --------------------------
# Main patch processing
# --------------------------
def process_patch(patch, mask_patch, x_offset, y_offset, axon_data, object_counter, output_image):
    patch = darken_and_sharpen(patch)
    gray = cv2.cvtColor(patch, cv2.COLOR_BGR2GRAY)

    # Contrast enhancement
    clahe = cv2.createCLAHE(clipLimit=2.5, tileGridSize=(8, 8))
    enhanced = clahe.apply(gray)

    # Thresholding
    blurred = cv2.GaussianBlur(enhanced, (3, 3), 0)
    _, otsu = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    adaptive = cv2.adaptiveThreshold(
        blurred, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
        cv2.THRESH_BINARY_INV, 35, 2
    )
    thresh = cv2.bitwise_or(otsu, adaptive)

    # Clean
    kernel = np.ones((3, 3), np.uint8)
    cleaned = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=1)

    contours, hierarchy = cv2.findContours(cleaned, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    if hierarchy is None:
        return object_counter
    hierarchy = hierarchy[0]

    for i, contour in enumerate(contours):
        if hierarchy[i][3] != -1:  # only outer contours
            continue

        area = cv2.contourArea(contour)
        if area < MIN_CONTOUR_AREA or area > MAX_CONTOUR_AREA:
            continue

        overlap = contour_overlap_ratio(contour, mask_patch)
        if overlap < TISSUE_OVERLAP_MIN:
            continue

        hull = cv2.convexHull(contour)
        solidity = area / (cv2.contourArea(hull) + 1e-6)
        circ = circularity(contour)
        if solidity < MIN_SOLIDITY or circ < MIN_CIRCULARITY:
            continue

        # Inner children
        inner_children = []
        for j, child in enumerate(contours):
            if hierarchy[j][3] == i and cv2.contourArea(child) > 30:
                inner_children.append(child)
        if len(inner_children) == 0:
            continue

        axon_type = "mature" if len(inner_children) == 1 else "regrowth_cluster"
        largest_inner = max(inner_children, key=cv2.contourArea)

        # Outer
        (x_outer, y_outer), outer_radius = cv2.minEnclosingCircle(contour)
        contour_shifted = contour + np.array([x_offset, y_offset])
        x_outer += x_offset
        y_outer += y_offset
        outer_area_px = cv2.contourArea(contour)
        outer_area_um2 = outer_area_px * (scale_factor**2)

        # Inner
        (x_inner, y_inner), inner_radius = cv2.minEnclosingCircle(largest_inner)
        inner_shifted = largest_inner + np.array([x_offset, y_offset])
        cv2.drawContours(output_image, [contour_shifted], -1, (255, 0, 0), 1)
        cv2.drawContours(output_image, [inner_shifted], -1, (0, 255, 0), 1)
        inner_area_px = cv2.contourArea(largest_inner)
        inner_area_um2 = inner_area_px * (scale_factor**2)

        # Metrics
        thickness = (outer_radius - inner_radius) * scale_factor
        g_ratio = inner_radius / (outer_radius + 1e-6)

        axon_data.append({
            "axon_id": object_counter,
            "axon_type": axon_type,
            "outer_radius": outer_radius * scale_factor,
            "inner_radius": inner_radius * scale_factor,
            "thickness": thickness,
            "inner_diameter": (2 * inner_radius) * scale_factor,
            "axon_diameter": (2 * inner_radius) * scale_factor,  # <-- INNER diameter
            "outer_area": outer_area_um2,
            "inner_area": inner_area_um2,
            "g_ratio": g_ratio
        })

        # Numbering
        cv2.putText(output_image, str(object_counter),
                    (int(x_outer), int(y_outer)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)

        object_counter += 1

    return object_counter

# --------------------------
# Whole image tiling
# --------------------------
def process_image(image_path, patch_size=1024):
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    if image is None:
        raise ValueError("Could not read image")

    tissue_mask_full = build_tissue_mask(image)
    h, w = image.shape[:2]
    output_image = image.copy()
    axon_data = []
    object_counter = 1

    for y in range(0, h, patch_size):
        for x in range(0, w, patch_size):
            patch = image[y:y+patch_size, x:x+patch_size]
            mask_patch = tissue_mask_full[y:y+patch_size, x:x+patch_size]
            object_counter = process_patch(
                patch, mask_patch, x, y, axon_data, object_counter, output_image
            )

    filename = os.path.basename(image_path)
    output_path = os.path.join(output_folder, f"numbered_{filename}")
    cv2.imwrite(output_path, output_image)

    print(f"\nProcessed: {filename}")
    print(f"Axons detected: {len(axon_data)}\n")
    return axon_data, output_image

# --------------------------
# Save data to CSV
# --------------------------
def save_to_csv(axon_data, output_folder, filename="axon_measurements.csv"):
    df = pd.DataFrame(axon_data)
    csv_path = os.path.join(output_folder, filename)
    df.to_csv(csv_path, index=False)
    print(f"✅ Axon data saved to: {csv_path}")
    return df

# --------------------------
# Scatter: Diameter vs g-ratio
# --------------------------
def plot_diameter_vs_gratio(df, output_folder):
    plt.figure(figsize=(7, 5))

    # Scatter for mature axons
    mature = df[df["axon_type"] == "mature"]
    plt.scatter(
        mature["axon_diameter"], mature["g_ratio"],
        c="blue", label="Mature", alpha=0.7, edgecolor="k", s=50
    )

    # Scatter for regenerating axons
    regrowth = df[df["axon_type"] == "regrowth_cluster"]
    plt.scatter(
        regrowth["axon_diameter"], regrowth["g_ratio"],
        c="red", label="Regrowth", alpha=0.7, edgecolor="k", s=50
    )

    plt.xlabel("Inner Axon Diameter (µm)")
    plt.ylabel("G-ratio")
    plt.title("Inner-based Axon Diameter vs G-ratio")
    plt.legend()
    plt.grid(True, linestyle="--", alpha=0.5)

    out_path = os.path.join(output_folder, "axon_diameter_vs_g_ratio.png")
    plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.close()

    print(f"📈 Scatter plot saved: {out_path}")


# --------------------------
# Summary statistics
# --------------------------
# --------------------------
# Summary statistics (Diameter + Thickness)
# --------------------------
def summarize_statistics(df, output_folder):
    stats = {}

    for axon_type, subset in {
        "Regrowth Axons": df[df["axon_type"] == "regrowth_cluster"],
        "Mature Axons": df[df["axon_type"] == "mature"],
        "All Axons": df
    }.items():
        if len(subset) == 0:
            continue
        stats[axon_type] = {
            "Diameter_min": subset["axon_diameter"].min(),
            "Diameter_max": subset["axon_diameter"].max(),
            "Diameter_mean": subset["axon_diameter"].mean(),
            "Diameter_median": subset["axon_diameter"].median(),
            "Thickness_min": subset["thickness"].min(),
            "Thickness_max": subset["thickness"].max(),
            "Thickness_mean": subset["thickness"].mean(),
            "Thickness_median": subset["thickness"].median()
        }

    # Convert to dataframe for pretty export
    stats_df = pd.DataFrame(stats).T.round(3)  # round to 3 decimals
    csv_path = os.path.join(output_folder, "axon_summary_statistics.csv")
    stats_df.to_csv(csv_path)
    print(f"📊 Summary statistics saved: {csv_path}")
    print(stats_df)

    return stats_df

# --------------------------
# Scatter: Diameter vs Thickness
# --------------------------
def plot_diameter_vs_thickness(df, output_folder):
    plt.figure(figsize=(7, 5))

    # Mature axons → open circles (rings)
    mature = df[df["axon_type"] == "mature"]
    plt.scatter(
        mature["axon_diameter"], mature["thickness"],
        facecolors='none', edgecolors="blue", label="Mature", s=70, linewidth=1.2
    )

    # Regrowth axons → solid dots
    regrowth = df[df["axon_type"] == "regrowth_cluster"]
    plt.scatter(
        regrowth["axon_diameter"], regrowth["thickness"],
        c="red", label="Regrowth", s=60, alpha=0.8
    )

    plt.xlabel("Inner Axon Diameter (µm)")
    plt.ylabel("Myelin Thickness (µm)")
    plt.title("Inner Axon Diameter vs Myelin Thickness")
    plt.legend()
    plt.grid(True, linestyle="--", alpha=0.5)

    out_path = os.path.join(output_folder, "axon_diameter_vs_thickness.png")
    plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.close()

    print(f"📈 Scatter plot saved: {out_path}")

# --------------------------
# Run Pipeline
# --------------------------
axon_data, output_image = process_image(image_path, patch_size=1024)
df = save_to_csv(axon_data, output_folder)
plot_diameter_vs_gratio(df, output_folder)
plot_diameter_vs_thickness(df, output_folder) 
summarize_statistics(df, output_folder)
print(f"\n✅ Done: CSV, scatter plot saved in '{output_folder}'")
#gratio vs inner diameter, inner diamter vs thickness and has the mean median min max of diamter and thickness
# Out:
# Processed: low density clip 2.png
# Axons detected: 125
#
# ✅ Axon data saved to: C:\Users\sanje\Downloads\lowdensity_qwerty5_4_statistics_regrowthandmature_gvsdia2\axon_measurements.csv
# 📈 Scatter plot saved: C:\Users\sanje\Downloads\lowdensity_qwerty5_4_statistics_regrowthandmature_gvsdia2\axon_diameter_vs_g_ratio.png
# 📈 Scatter plot saved: C:\Users\sanje\Downloads\lowdensity_qwerty5_4_statistics_regrowthandmature_gvsdia2\axon_diameter_vs_thickness.png
# 📊 Summary statistics saved: C:\Users\sanje\Downloads\lowdensity_qwerty5_4_statistics_regrowthandmature_gvsdia2\axon_summary_statistics.csv
#                 Diameter_min  Diameter_max  Diameter_mean  Diameter_median  \
# Regrowth Axons         1.566        10.888          4.227            3.662
# Mature Axons           1.122         7.849          2.989            2.880
# All Axons              1.122        10.888          3.256            2.907
#
#                 Thickness_min  Thickness_max  Thickness_mean  Thickness_median
# Regrowth Axons          0.947         19.835           3.872             2.545
# Mature Axons            0.440         15.379           2.096             1.284
# All Axons               0.440         19.835           2.480             1.592
#
# ✅ Done: CSV, scatter plot saved in 'C:\Users\sanje\Downloads\lowdensity_qwerty5_4_statistics_regrowthandmature_gvsdia2'
